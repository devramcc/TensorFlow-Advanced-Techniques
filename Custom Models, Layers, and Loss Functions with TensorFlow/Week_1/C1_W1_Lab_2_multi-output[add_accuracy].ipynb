# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': [tf.keras.metrics.RootMeanSquaredError(), 'accuracy'],
                       'y2_output': [tf.keras.metrics.RootMeanSquaredError(), 'accuracy'],
                      })

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 962us/sample - loss: 0.3164 - y1_output_loss: 0.1100 - y2_output_loss: 0.2073 - y1_output_root_mean_squared_error: 0.3323 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4539 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6637 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.5275 - val_y1_output_root_mean_squared_error: 0.4301 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6919 - val_y2_output_accuracy: 0.0000e+00
# Epoch 2/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.3436 - y1_output_loss: 0.1313 - y2_output_loss: 0.2127 - y1_output_root_mean_squared_error: 0.3632 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4601 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7592 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 0.6111 - val_y1_output_root_mean_squared_error: 0.4519 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7450 - val_y2_output_accuracy: 0.0000e+00
# Epoch 3/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3991 - y1_output_loss: 0.1431 - y2_output_loss: 0.2531 - y1_output_root_mean_squared_error: 0.3797 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5049 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6125 - val_y1_output_loss: 0.1530 - val_y2_output_loss: 0.5009 - val_y1_output_root_mean_squared_error: 0.3961 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6749 - val_y2_output_accuracy: 0.0000e+00
# Epoch 4/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3198 - y1_output_loss: 0.1246 - y2_output_loss: 0.2091 - y1_output_root_mean_squared_error: 0.3363 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4546 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.0185 - val_y1_output_loss: 0.3061 - val_y2_output_loss: 0.7768 - val_y1_output_root_mean_squared_error: 0.5585 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8405 - val_y2_output_accuracy: 0.0000e+00
# Epoch 5/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3143 - y1_output_loss: 0.1153 - y2_output_loss: 0.2075 - y1_output_root_mean_squared_error: 0.3399 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4459 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.2961 - val_y1_output_loss: 0.1652 - val_y2_output_loss: 1.1579 - val_y1_output_root_mean_squared_error: 0.4125 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.0611 - val_y2_output_accuracy: 0.0000e+00
# Epoch 6/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3620 - y1_output_loss: 0.1165 - y2_output_loss: 0.2426 - y1_output_root_mean_squared_error: 0.3423 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4948 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7089 - val_y1_output_loss: 0.1926 - val_y2_output_loss: 0.5417 - val_y1_output_root_mean_squared_error: 0.4469 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7135 - val_y2_output_accuracy: 0.0000e+00
# Epoch 7/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2561 - y1_output_loss: 0.1007 - y2_output_loss: 0.1543 - y1_output_root_mean_squared_error: 0.3186 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3932 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8543 - val_y1_output_loss: 0.1857 - val_y2_output_loss: 0.6948 - val_y1_output_root_mean_squared_error: 0.4378 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8140 - val_y2_output_accuracy: 0.0000e+00
# Epoch 8/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4347 - y1_output_loss: 0.1426 - y2_output_loss: 0.2917 - y1_output_root_mean_squared_error: 0.3791 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5395 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7362 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.5548 - val_y1_output_root_mean_squared_error: 0.4416 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7357 - val_y2_output_accuracy: 0.0000e+00
# Epoch 9/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.2937 - y1_output_loss: 0.1108 - y2_output_loss: 0.1821 - y1_output_root_mean_squared_error: 0.3323 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4281 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6730 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.5293 - val_y1_output_root_mean_squared_error: 0.4325 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6971 - val_y2_output_accuracy: 0.0000e+00
# Epoch 10/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3333 - y1_output_loss: 0.1075 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3265 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4761 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7524 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 0.5380 - val_y1_output_root_mean_squared_error: 0.5046 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7056 - val_y2_output_accuracy: 0.0000e+00
# Epoch 11/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3221 - y1_output_loss: 0.1144 - y2_output_loss: 0.2076 - y1_output_root_mean_squared_error: 0.3373 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4564 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6158 - val_y1_output_loss: 0.1561 - val_y2_output_loss: 0.4927 - val_y1_output_root_mean_squared_error: 0.4015 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6743 - val_y2_output_accuracy: 0.0000e+00
# Epoch 12/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3333 - y1_output_loss: 0.1180 - y2_output_loss: 0.2159 - y1_output_root_mean_squared_error: 0.3430 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4644 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7723 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 0.5855 - val_y1_output_root_mean_squared_error: 0.4878 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7310 - val_y2_output_accuracy: 0.0000e+00
# Epoch 13/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.3240 - y1_output_loss: 0.1258 - y2_output_loss: 0.1991 - y1_output_root_mean_squared_error: 0.3532 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4464 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6788 - val_y1_output_loss: 0.2288 - val_y2_output_loss: 0.4694 - val_y1_output_root_mean_squared_error: 0.4855 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6657 - val_y2_output_accuracy: 0.0000e+00
# Epoch 14/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4033 - y1_output_loss: 0.1315 - y2_output_loss: 0.2694 - y1_output_root_mean_squared_error: 0.3639 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5205 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6038 - val_y1_output_loss: 0.1541 - val_y2_output_loss: 0.4786 - val_y1_output_root_mean_squared_error: 0.3989 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6669 - val_y2_output_accuracy: 0.0000e+00
# Epoch 15/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3329 - y1_output_loss: 0.1145 - y2_output_loss: 0.2170 - y1_output_root_mean_squared_error: 0.3399 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4662 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7081 - val_y1_output_loss: 0.1880 - val_y2_output_loss: 0.5656 - val_y1_output_root_mean_squared_error: 0.4388 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7180 - val_y2_output_accuracy: 0.0000e+00
# Epoch 16/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.4052 - y1_output_loss: 0.1215 - y2_output_loss: 0.2808 - y1_output_root_mean_squared_error: 0.3489 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5324 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5971 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.4748 - val_y1_output_root_mean_squared_error: 0.4040 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6587 - val_y2_output_accuracy: 0.0000e+00
# Epoch 17/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3144 - y1_output_loss: 0.1116 - y2_output_loss: 0.2073 - y1_output_root_mean_squared_error: 0.3352 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4495 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.0974 - val_y1_output_loss: 0.2134 - val_y2_output_loss: 0.9310 - val_y1_output_root_mean_squared_error: 0.4666 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.9379 - val_y2_output_accuracy: 0.0000e+00
# Epoch 18/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3241 - y1_output_loss: 0.1166 - y2_output_loss: 0.2063 - y1_output_root_mean_squared_error: 0.3425 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4547 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5805 - val_y1_output_loss: 0.1453 - val_y2_output_loss: 0.4711 - val_y1_output_root_mean_squared_error: 0.3865 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6566 - val_y2_output_accuracy: 0.0000e+00
# Epoch 19/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3280 - y1_output_loss: 0.1126 - y2_output_loss: 0.2139 - y1_output_root_mean_squared_error: 0.3358 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4639 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5988 - val_y1_output_loss: 0.1538 - val_y2_output_loss: 0.4782 - val_y1_output_root_mean_squared_error: 0.3969 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6643 - val_y2_output_accuracy: 0.0000e+00
# Epoch 20/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3375 - y1_output_loss: 0.1111 - y2_output_loss: 0.2495 - y1_output_root_mean_squared_error: 0.3294 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4785 - y2_output_accuracy: 0.0000e+00 - val_loss: 3.1909 - val_y1_output_loss: 0.7660 - val_y2_output_loss: 2.4556 - val_y1_output_root_mean_squared_error: 0.8812 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.5539 - val_y2_output_accuracy: 0.0000e+00
# Epoch 21/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4368 - y1_output_loss: 0.1348 - y2_output_loss: 0.3024 - y1_output_root_mean_squared_error: 0.3677 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5492 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6246 - val_y1_output_loss: 0.1793 - val_y2_output_loss: 0.4886 - val_y1_output_root_mean_squared_error: 0.4288 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6639 - val_y2_output_accuracy: 0.0000e+00
# Epoch 22/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5244 - y1_output_loss: 0.1416 - y2_output_loss: 0.3793 - y1_output_root_mean_squared_error: 0.3770 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.6183 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6559 - val_y1_output_loss: 0.1409 - val_y2_output_loss: 0.5628 - val_y1_output_root_mean_squared_error: 0.3801 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7151 - val_y2_output_accuracy: 0.0000e+00
# Epoch 23/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3884 - y1_output_loss: 0.1456 - y2_output_loss: 0.2470 - y1_output_root_mean_squared_error: 0.3802 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4938 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.5143 - val_y1_output_loss: 0.5613 - val_y2_output_loss: 0.9597 - val_y1_output_root_mean_squared_error: 0.7579 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.9695 - val_y2_output_accuracy: 0.0000e+00
# Epoch 24/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5051 - y1_output_loss: 0.1771 - y2_output_loss: 0.3277 - y1_output_root_mean_squared_error: 0.4212 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5724 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8150 - val_y1_output_loss: 0.2192 - val_y2_output_loss: 0.6418 - val_y1_output_root_mean_squared_error: 0.4748 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7678 - val_y2_output_accuracy: 0.0000e+00
# Epoch 25/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3245 - y1_output_loss: 0.1189 - y2_output_loss: 0.2060 - y1_output_root_mean_squared_error: 0.3438 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4542 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.4340 - val_y1_output_loss: 0.6196 - val_y2_output_loss: 0.8578 - val_y1_output_root_mean_squared_error: 0.7939 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8965 - val_y2_output_accuracy: 0.0000e+00
# Epoch 26/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3947 - y1_output_loss: 0.1422 - y2_output_loss: 0.2500 - y1_output_root_mean_squared_error: 0.3787 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5013 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6550 - val_y1_output_loss: 0.1427 - val_y2_output_loss: 0.5407 - val_y1_output_root_mean_squared_error: 0.3823 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7133 - val_y2_output_accuracy: 0.0000e+00
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2901 - y1_output_loss: 0.1004 - y2_output_loss: 0.1886 - y1_output_root_mean_squared_error: 0.3182 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4345 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6311 - val_y1_output_loss: 0.1541 - val_y2_output_loss: 0.5155 - val_y1_output_root_mean_squared_error: 0.3982 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6874 - val_y2_output_accuracy: 0.0000e+00
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2889 - y1_output_loss: 0.1016 - y2_output_loss: 0.1860 - y1_output_root_mean_squared_error: 0.3191 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4325 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5581 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.4349 - val_y1_output_root_mean_squared_error: 0.4038 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6285 - val_y2_output_accuracy: 0.0000e+00
# Epoch 29/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4987 - y1_output_loss: 0.1298 - y2_output_loss: 0.3693 - y1_output_root_mean_squared_error: 0.3604 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.6073 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6367 - val_y1_output_loss: 0.1441 - val_y2_output_loss: 0.5374 - val_y1_output_root_mean_squared_error: 0.3838 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6995 - val_y2_output_accuracy: 0.0000e+00
# Epoch 30/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3459 - y1_output_loss: 0.1145 - y2_output_loss: 0.2302 - y1_output_root_mean_squared_error: 0.3396 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4802 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6382 - val_y1_output_loss: 0.1623 - val_y2_output_loss: 0.5101 - val_y1_output_root_mean_squared_error: 0.4079 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6869 - val_y2_output_accuracy: 0.0000e+00
# Epoch 31/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4316 - y1_output_loss: 0.1374 - y2_output_loss: 0.2918 - y1_output_root_mean_squared_error: 0.3717 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5417 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5653 - val_y1_output_loss: 0.1322 - val_y2_output_loss: 0.4738 - val_y1_output_root_mean_squared_error: 0.3694 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6549 - val_y2_output_accuracy: 0.0000e+00
# Epoch 32/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4337 - y1_output_loss: 0.1247 - y2_output_loss: 0.3066 - y1_output_root_mean_squared_error: 0.3539 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5554 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7149 - val_y1_output_loss: 0.1499 - val_y2_output_loss: 0.5962 - val_y1_output_root_mean_squared_error: 0.3930 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7486 - val_y2_output_accuracy: 0.0000e+00
# Epoch 33/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3304 - y1_output_loss: 0.1147 - y2_output_loss: 0.2158 - y1_output_root_mean_squared_error: 0.3389 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4642 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.9587 - val_y1_output_loss: 0.3186 - val_y2_output_loss: 0.6697 - val_y1_output_root_mean_squared_error: 0.5700 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7961 - val_y2_output_accuracy: 0.0000e+00
# Epoch 34/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3735 - y1_output_loss: 0.1226 - y2_output_loss: 0.2511 - y1_output_root_mean_squared_error: 0.3509 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5004 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7077 - val_y1_output_loss: 0.1828 - val_y2_output_loss: 0.5504 - val_y1_output_root_mean_squared_error: 0.4351 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7200 - val_y2_output_accuracy: 0.0000e+00
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3043 - y1_output_loss: 0.1164 - y2_output_loss: 0.1860 - y1_output_root_mean_squared_error: 0.3420 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4328 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6726 - val_y1_output_loss: 0.1589 - val_y2_output_loss: 0.5396 - val_y1_output_root_mean_squared_error: 0.4044 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7135 - val_y2_output_accuracy: 0.0000e+00
# Epoch 36/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3224 - y1_output_loss: 0.1161 - y2_output_loss: 0.2069 - y1_output_root_mean_squared_error: 0.3410 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4540 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7452 - val_y1_output_loss: 0.1759 - val_y2_output_loss: 0.6099 - val_y1_output_root_mean_squared_error: 0.4250 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7514 - val_y2_output_accuracy: 0.0000e+00
# Epoch 37/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3771 - y1_output_loss: 0.1277 - y2_output_loss: 0.2517 - y1_output_root_mean_squared_error: 0.3580 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4990 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.2043 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 1.0024 - val_y1_output_root_mean_squared_error: 0.4977 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.9781 - val_y2_output_accuracy: 0.0000e+00
# Epoch 38/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3435 - y1_output_loss: 0.1169 - y2_output_loss: 0.2249 - y1_output_root_mean_squared_error: 0.3431 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4752 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6100 - val_y1_output_loss: 0.1813 - val_y2_output_loss: 0.4621 - val_y1_output_root_mean_squared_error: 0.4323 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6505 - val_y2_output_accuracy: 0.0000e+00
# Epoch 39/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4734 - y1_output_loss: 0.1499 - y2_output_loss: 0.3221 - y1_output_root_mean_squared_error: 0.3864 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5693 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5927 - val_y1_output_loss: 0.1610 - val_y2_output_loss: 0.4631 - val_y1_output_root_mean_squared_error: 0.4079 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6530 - val_y2_output_accuracy: 0.0000e+00
# Epoch 40/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3436 - y1_output_loss: 0.1152 - y2_output_loss: 0.2288 - y1_output_root_mean_squared_error: 0.3367 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4798 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6075 - val_y1_output_loss: 0.1412 - val_y2_output_loss: 0.4942 - val_y1_output_root_mean_squared_error: 0.3820 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6794 - val_y2_output_accuracy: 0.0000e+00
# Epoch 41/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.9841 - y1_output_loss: 0.2271 - y2_output_loss: 0.7499 - y1_output_root_mean_squared_error: 0.4780 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.8693 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5875 - val_y1_output_loss: 0.1585 - val_y2_output_loss: 0.4596 - val_y1_output_root_mean_squared_error: 0.4042 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6512 - val_y2_output_accuracy: 0.0000e+00
# Epoch 42/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3450 - y1_output_loss: 0.1330 - y2_output_loss: 0.2100 - y1_output_root_mean_squared_error: 0.3651 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4602 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.0706 - val_y1_output_loss: 0.2929 - val_y2_output_loss: 0.8069 - val_y1_output_root_mean_squared_error: 0.5475 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8780 - val_y2_output_accuracy: 0.0000e+00
# Epoch 43/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3889 - y1_output_loss: 0.1440 - y2_output_loss: 0.2446 - y1_output_root_mean_squared_error: 0.3794 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4949 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6474 - val_y1_output_loss: 0.1585 - val_y2_output_loss: 0.5202 - val_y1_output_root_mean_squared_error: 0.4049 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6953 - val_y2_output_accuracy: 0.0000e+00
# Epoch 44/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3009 - y1_output_loss: 0.1133 - y2_output_loss: 0.1961 - y1_output_root_mean_squared_error: 0.3311 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4374 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.9844 - val_y1_output_loss: 0.7555 - val_y2_output_loss: 1.2374 - val_y1_output_root_mean_squared_error: 0.8759 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.1033 - val_y2_output_accuracy: 0.0000e+00
# Epoch 45/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4087 - y1_output_loss: 0.1379 - y2_output_loss: 0.2686 - y1_output_root_mean_squared_error: 0.3720 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5199 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8007 - val_y1_output_loss: 0.1441 - val_y2_output_loss: 0.6794 - val_y1_output_root_mean_squared_error: 0.3859 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8073 - val_y2_output_accuracy: 0.0000e+00
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2838 - y1_output_loss: 0.1109 - y2_output_loss: 0.1715 - y1_output_root_mean_squared_error: 0.3335 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4155 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5597 - val_y1_output_loss: 0.1462 - val_y2_output_loss: 0.4331 - val_y1_output_root_mean_squared_error: 0.3892 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6389 - val_y2_output_accuracy: 0.0000e+00
# Epoch 47/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2785 - y1_output_loss: 0.1012 - y2_output_loss: 0.1778 - y1_output_root_mean_squared_error: 0.3189 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4205 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8427 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 0.6733 - val_y1_output_root_mean_squared_error: 0.4269 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8127 - val_y2_output_accuracy: 0.0000e+00
# Epoch 48/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2743 - y1_output_loss: 0.1028 - y2_output_loss: 0.1693 - y1_output_root_mean_squared_error: 0.3221 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4130 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7339 - val_y1_output_loss: 0.2658 - val_y2_output_loss: 0.4889 - val_y1_output_root_mean_squared_error: 0.5205 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6804 - val_y2_output_accuracy: 0.0000e+00
# Epoch 49/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.4392 - y1_output_loss: 0.1424 - y2_output_loss: 0.2961 - y1_output_root_mean_squared_error: 0.3784 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5441 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7455 - val_y1_output_loss: 0.1283 - val_y2_output_loss: 0.6697 - val_y1_output_root_mean_squared_error: 0.3637 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7831 - val_y2_output_accuracy: 0.0000e+00
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2908 - y1_output_loss: 0.1035 - y2_output_loss: 0.1883 - y1_output_root_mean_squared_error: 0.3217 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4327 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.1409 - val_y1_output_loss: 0.3364 - val_y2_output_loss: 0.8235 - val_y1_output_root_mean_squared_error: 0.5857 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8932 - val_y2_output_accuracy: 0.0000e+00
# Epoch 51/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3890 - y1_output_loss: 0.1187 - y2_output_loss: 0.2684 - y1_output_root_mean_squared_error: 0.3438 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5205 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7146 - val_y1_output_loss: 0.2319 - val_y2_output_loss: 0.5255 - val_y1_output_root_mean_squared_error: 0.4880 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6903 - val_y2_output_accuracy: 0.0000e+00
# Epoch 52/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2400 - y1_output_loss: 0.1080 - y2_output_loss: 0.1333 - y1_output_root_mean_squared_error: 0.3296 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3624 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6370 - val_y1_output_loss: 0.1552 - val_y2_output_loss: 0.5131 - val_y1_output_root_mean_squared_error: 0.3996 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6909 - val_y2_output_accuracy: 0.0000e+00
# Epoch 53/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3020 - y1_output_loss: 0.1121 - y2_output_loss: 0.1905 - y1_output_root_mean_squared_error: 0.3337 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4367 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.2967 - val_y1_output_loss: 0.3842 - val_y2_output_loss: 0.9779 - val_y1_output_root_mean_squared_error: 0.6218 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.9540 - val_y2_output_accuracy: 0.0000e+00
# Epoch 54/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4430 - y1_output_loss: 0.1428 - y2_output_loss: 0.2976 - y1_output_root_mean_squared_error: 0.3786 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5474 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6382 - val_y1_output_loss: 0.1882 - val_y2_output_loss: 0.4817 - val_y1_output_root_mean_squared_error: 0.4368 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6689 - val_y2_output_accuracy: 0.0000e+00
# Epoch 55/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3507 - y1_output_loss: 0.1389 - y2_output_loss: 0.2112 - y1_output_root_mean_squared_error: 0.3730 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4599 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5623 - val_y1_output_loss: 0.1548 - val_y2_output_loss: 0.4461 - val_y1_output_root_mean_squared_error: 0.3968 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6362 - val_y2_output_accuracy: 0.0000e+00
# Epoch 56/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3549 - y1_output_loss: 0.1333 - y2_output_loss: 0.2253 - y1_output_root_mean_squared_error: 0.3591 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4754 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.9351 - val_y1_output_loss: 0.3597 - val_y2_output_loss: 0.6371 - val_y1_output_root_mean_squared_error: 0.6003 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7582 - val_y2_output_accuracy: 0.0000e+00
# Epoch 57/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3691 - y1_output_loss: 0.1219 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3484 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4977 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5771 - val_y1_output_loss: 0.1570 - val_y2_output_loss: 0.4509 - val_y1_output_root_mean_squared_error: 0.4003 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6457 - val_y2_output_accuracy: 0.0000e+00
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2884 - y1_output_loss: 0.1123 - y2_output_loss: 0.1749 - y1_output_root_mean_squared_error: 0.3364 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4185 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6280 - val_y1_output_loss: 0.1724 - val_y2_output_loss: 0.4755 - val_y1_output_root_mean_squared_error: 0.4214 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6711 - val_y2_output_accuracy: 0.0000e+00
# Epoch 59/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2942 - y1_output_loss: 0.1132 - y2_output_loss: 0.1792 - y1_output_root_mean_squared_error: 0.3370 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4250 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5599 - val_y1_output_loss: 0.1713 - val_y2_output_loss: 0.4146 - val_y1_output_root_mean_squared_error: 0.4186 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6202 - val_y2_output_accuracy: 0.0000e+00
# Epoch 60/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3126 - y1_output_loss: 0.1092 - y2_output_loss: 0.2036 - y1_output_root_mean_squared_error: 0.3290 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4521 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5454 - val_y1_output_loss: 0.1415 - val_y2_output_loss: 0.4349 - val_y1_output_root_mean_squared_error: 0.3818 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6322 - val_y2_output_accuracy: 0.0000e+00
# Epoch 61/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2458 - y1_output_loss: 0.0999 - y2_output_loss: 0.1456 - y1_output_root_mean_squared_error: 0.3167 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3814 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6288 - val_y1_output_loss: 0.1379 - val_y2_output_loss: 0.5137 - val_y1_output_root_mean_squared_error: 0.3773 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6975 - val_y2_output_accuracy: 0.0000e+00
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3133 - y1_output_loss: 0.1143 - y2_output_loss: 0.1996 - y1_output_root_mean_squared_error: 0.3350 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4484 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6346 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 0.4528 - val_y1_output_root_mean_squared_error: 0.4508 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6568 - val_y2_output_accuracy: 0.0000e+00
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2439 - y1_output_loss: 0.0999 - y2_output_loss: 0.1436 - y1_output_root_mean_squared_error: 0.3163 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3793 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6427 - val_y1_output_loss: 0.1577 - val_y2_output_loss: 0.5089 - val_y1_output_root_mean_squared_error: 0.4039 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6925 - val_y2_output_accuracy: 0.0000e+00
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3066 - y1_output_loss: 0.1138 - y2_output_loss: 0.1983 - y1_output_root_mean_squared_error: 0.3375 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4390 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.3284 - val_y1_output_loss: 0.2097 - val_y2_output_loss: 1.1616 - val_y1_output_root_mean_squared_error: 0.4632 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.0554 - val_y2_output_accuracy: 0.0000e+00
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3621 - y1_output_loss: 0.1201 - y2_output_loss: 0.2423 - y1_output_root_mean_squared_error: 0.3457 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4926 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.5465 - val_y1_output_loss: 0.4803 - val_y2_output_loss: 1.0932 - val_y1_output_root_mean_squared_error: 0.7005 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.0275 - val_y2_output_accuracy: 0.0000e+00
# Epoch 66/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3577 - y1_output_loss: 0.1311 - y2_output_loss: 0.2255 - y1_output_root_mean_squared_error: 0.3630 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4753 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7819 - val_y1_output_loss: 0.1933 - val_y2_output_loss: 0.6143 - val_y1_output_root_mean_squared_error: 0.4467 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7631 - val_y2_output_accuracy: 0.0000e+00
# Epoch 67/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2857 - y1_output_loss: 0.1036 - y2_output_loss: 0.1800 - y1_output_root_mean_squared_error: 0.3227 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4261 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5496 - val_y1_output_loss: 0.1458 - val_y2_output_loss: 0.4334 - val_y1_output_root_mean_squared_error: 0.3876 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6320 - val_y2_output_accuracy: 0.0000e+00
# Epoch 68/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3411 - y1_output_loss: 0.1078 - y2_output_loss: 0.2305 - y1_output_root_mean_squared_error: 0.3294 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4822 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6727 - val_y1_output_loss: 0.1526 - val_y2_output_loss: 0.5561 - val_y1_output_root_mean_squared_error: 0.3958 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7184 - val_y2_output_accuracy: 0.0000e+00
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3551 - y1_output_loss: 0.1122 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3362 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4920 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5538 - val_y1_output_loss: 0.1584 - val_y2_output_loss: 0.4323 - val_y1_output_root_mean_squared_error: 0.4044 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6248 - val_y2_output_accuracy: 0.0000e+00
# Epoch 70/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3149 - y1_output_loss: 0.1094 - y2_output_loss: 0.2034 - y1_output_root_mean_squared_error: 0.3312 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4530 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6007 - val_y1_output_loss: 0.1773 - val_y2_output_loss: 0.4439 - val_y1_output_root_mean_squared_error: 0.4284 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6459 - val_y2_output_accuracy: 0.0000e+00
# Epoch 71/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2992 - y1_output_loss: 0.1127 - y2_output_loss: 0.1873 - y1_output_root_mean_squared_error: 0.3354 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4321 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7640 - val_y1_output_loss: 0.1629 - val_y2_output_loss: 0.6144 - val_y1_output_root_mean_squared_error: 0.4100 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7720 - val_y2_output_accuracy: 0.0000e+00
# Epoch 72/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3164 - y1_output_loss: 0.1248 - y2_output_loss: 0.1930 - y1_output_root_mean_squared_error: 0.3523 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4386 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7851 - val_y1_output_loss: 0.2141 - val_y2_output_loss: 0.5856 - val_y1_output_root_mean_squared_error: 0.4710 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7505 - val_y2_output_accuracy: 0.0000e+00
# Epoch 73/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4300 - y1_output_loss: 0.1323 - y2_output_loss: 0.2975 - y1_output_root_mean_squared_error: 0.3636 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5457 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.9570 - val_y1_output_loss: 0.3126 - val_y2_output_loss: 0.6764 - val_y1_output_root_mean_squared_error: 0.5643 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7991 - val_y2_output_accuracy: 0.0000e+00
# Epoch 74/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2527 - y1_output_loss: 0.1059 - y2_output_loss: 0.1462 - y1_output_root_mean_squared_error: 0.3263 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3825 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5346 - val_y1_output_loss: 0.1452 - val_y2_output_loss: 0.4180 - val_y1_output_root_mean_squared_error: 0.3876 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6199 - val_y2_output_accuracy: 0.0000e+00
# Epoch 75/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3256 - y1_output_loss: 0.1158 - y2_output_loss: 0.2121 - y1_output_root_mean_squared_error: 0.3406 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4578 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5694 - val_y1_output_loss: 0.1629 - val_y2_output_loss: 0.4392 - val_y1_output_root_mean_squared_error: 0.4081 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6347 - val_y2_output_accuracy: 0.0000e+00
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2686 - y1_output_loss: 0.1022 - y2_output_loss: 0.1667 - y1_output_root_mean_squared_error: 0.3194 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4082 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.2774 - val_y1_output_loss: 0.4662 - val_y2_output_loss: 0.8410 - val_y1_output_root_mean_squared_error: 0.6898 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8953 - val_y2_output_accuracy: 0.0000e+00
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3421 - y1_output_loss: 0.1271 - y2_output_loss: 0.2145 - y1_output_root_mean_squared_error: 0.3572 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4631 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7265 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.5552 - val_y1_output_root_mean_squared_error: 0.4468 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7259 - val_y2_output_accuracy: 0.0000e+00
# Epoch 78/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5031 - y1_output_loss: 0.1621 - y2_output_loss: 0.3375 - y1_output_root_mean_squared_error: 0.4043 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5828 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6524 - val_y1_output_loss: 0.1693 - val_y2_output_loss: 0.5060 - val_y1_output_root_mean_squared_error: 0.4173 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6915 - val_y2_output_accuracy: 0.0000e+00
# Epoch 79/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4199 - y1_output_loss: 0.1412 - y2_output_loss: 0.2822 - y1_output_root_mean_squared_error: 0.3753 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5283 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.1424 - val_y1_output_loss: 0.4233 - val_y2_output_loss: 0.7680 - val_y1_output_root_mean_squared_error: 0.6508 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8479 - val_y2_output_accuracy: 0.0000e+00
# Epoch 80/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4612 - y1_output_loss: 0.1507 - y2_output_loss: 0.3135 - y1_output_root_mean_squared_error: 0.3866 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5584 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8495 - val_y1_output_loss: 0.3427 - val_y2_output_loss: 0.5355 - val_y1_output_root_mean_squared_error: 0.5921 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7064 - val_y2_output_accuracy: 0.0000e+00
# Epoch 81/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4273 - y1_output_loss: 0.1211 - y2_output_loss: 0.3069 - y1_output_root_mean_squared_error: 0.3491 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5527 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.1720 - val_y1_output_loss: 0.3063 - val_y2_output_loss: 0.8982 - val_y1_output_root_mean_squared_error: 0.5566 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.9285 - val_y2_output_accuracy: 0.0000e+00
# Epoch 82/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3277 - y1_output_loss: 0.1248 - y2_output_loss: 0.2010 - y1_output_root_mean_squared_error: 0.3541 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4498 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5983 - val_y1_output_loss: 0.1615 - val_y2_output_loss: 0.4717 - val_y1_output_root_mean_squared_error: 0.4058 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6585 - val_y2_output_accuracy: 0.0000e+00
# Epoch 83/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3024 - y1_output_loss: 0.1288 - y2_output_loss: 0.1746 - y1_output_root_mean_squared_error: 0.3564 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4188 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6081 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 0.4734 - val_y1_output_root_mean_squared_error: 0.4266 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6528 - val_y2_output_accuracy: 0.0000e+00
# Epoch 84/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2499 - y1_output_loss: 0.1069 - y2_output_loss: 0.1418 - y1_output_root_mean_squared_error: 0.3279 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3773 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5777 - val_y1_output_loss: 0.1913 - val_y2_output_loss: 0.4150 - val_y1_output_root_mean_squared_error: 0.4443 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6167 - val_y2_output_accuracy: 0.0000e+00
# Epoch 85/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3607 - y1_output_loss: 0.1233 - y2_output_loss: 0.2386 - y1_output_root_mean_squared_error: 0.3487 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4890 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.0432 - val_y1_output_loss: 0.4149 - val_y2_output_loss: 0.6532 - val_y1_output_root_mean_squared_error: 0.6503 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7876 - val_y2_output_accuracy: 0.0000e+00
# Epoch 86/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2680 - y1_output_loss: 0.1057 - y2_output_loss: 0.1669 - y1_output_root_mean_squared_error: 0.3246 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4033 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5642 - val_y1_output_loss: 0.1437 - val_y2_output_loss: 0.4657 - val_y1_output_root_mean_squared_error: 0.3829 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6462 - val_y2_output_accuracy: 0.0000e+00
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3061 - y1_output_loss: 0.1132 - y2_output_loss: 0.1914 - y1_output_root_mean_squared_error: 0.3380 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4380 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6761 - val_y1_output_loss: 0.1533 - val_y2_output_loss: 0.5353 - val_y1_output_root_mean_squared_error: 0.3983 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7193 - val_y2_output_accuracy: 0.0000e+00
# Epoch 88/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4884 - y1_output_loss: 0.1540 - y2_output_loss: 0.3308 - y1_output_root_mean_squared_error: 0.3942 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5770 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7304 - val_y1_output_loss: 0.1488 - val_y2_output_loss: 0.6339 - val_y1_output_root_mean_squared_error: 0.3889 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7611 - val_y2_output_accuracy: 0.0000e+00
# Epoch 89/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3226 - y1_output_loss: 0.1127 - y2_output_loss: 0.2125 - y1_output_root_mean_squared_error: 0.3353 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4584 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8571 - val_y1_output_loss: 0.1943 - val_y2_output_loss: 0.6700 - val_y1_output_root_mean_squared_error: 0.4481 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8101 - val_y2_output_accuracy: 0.0000e+00
# Epoch 90/500
# ...
# Epoch 472/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2328 - y1_output_loss: 0.0794 - y2_output_loss: 0.1530 - y1_output_root_mean_squared_error: 0.2820 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3915 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4581 - val_y1_output_loss: 0.1404 - val_y2_output_loss: 0.3377 - val_y1_output_root_mean_squared_error: 0.3777 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5617 - val_y2_output_accuracy: 0.0000e+00
# Epoch 473/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1742 - y1_output_loss: 0.0849 - y2_output_loss: 0.0881 - y1_output_root_mean_squared_error: 0.2926 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2977 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4526 - val_y1_output_loss: 0.1304 - val_y2_output_loss: 0.3340 - val_y1_output_root_mean_squared_error: 0.3645 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5655 - val_y2_output_accuracy: 0.0000e+00
# Epoch 474/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1793 - y1_output_loss: 0.0777 - y2_output_loss: 0.1012 - y1_output_root_mean_squared_error: 0.2795 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3181 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6222 - val_y1_output_loss: 0.1610 - val_y2_output_loss: 0.4728 - val_y1_output_root_mean_squared_error: 0.4076 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6754 - val_y2_output_accuracy: 0.0000e+00
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2957 - y1_output_loss: 0.0938 - y2_output_loss: 0.1993 - y1_output_root_mean_squared_error: 0.3075 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.4485 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4920 - val_y1_output_loss: 0.1251 - val_y2_output_loss: 0.3832 - val_y1_output_root_mean_squared_error: 0.3572 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6037 - val_y2_output_accuracy: 0.0000e+00
# Epoch 476/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2444 - y1_output_loss: 0.0926 - y2_output_loss: 0.1498 - y1_output_root_mean_squared_error: 0.3055 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3887 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4959 - val_y1_output_loss: 0.1372 - val_y2_output_loss: 0.3794 - val_y1_output_root_mean_squared_error: 0.3741 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5966 - val_y2_output_accuracy: 0.0000e+00
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1589 - y1_output_loss: 0.0720 - y2_output_loss: 0.0860 - y1_output_root_mean_squared_error: 0.2687 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2944 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5346 - val_y1_output_loss: 0.1573 - val_y2_output_loss: 0.3862 - val_y1_output_root_mean_squared_error: 0.4034 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6099 - val_y2_output_accuracy: 0.0000e+00
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1572 - y1_output_loss: 0.0779 - y2_output_loss: 0.0794 - y1_output_root_mean_squared_error: 0.2788 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2820 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4967 - val_y1_output_loss: 0.1532 - val_y2_output_loss: 0.3515 - val_y1_output_root_mean_squared_error: 0.3985 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5813 - val_y2_output_accuracy: 0.0000e+00
# Epoch 479/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.1994 - y1_output_loss: 0.0834 - y2_output_loss: 0.1155 - y1_output_root_mean_squared_error: 0.2889 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3405 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4811 - val_y1_output_loss: 0.1400 - val_y2_output_loss: 0.3524 - val_y1_output_root_mean_squared_error: 0.3773 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5820 - val_y2_output_accuracy: 0.0000e+00
# Epoch 480/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1661 - y1_output_loss: 0.0778 - y2_output_loss: 0.0891 - y1_output_root_mean_squared_error: 0.2785 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2975 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5261 - val_y1_output_loss: 0.1450 - val_y2_output_loss: 0.4008 - val_y1_output_root_mean_squared_error: 0.3850 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6147 - val_y2_output_accuracy: 0.0000e+00
# Epoch 481/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.1623 - y1_output_loss: 0.0786 - y2_output_loss: 0.0838 - y1_output_root_mean_squared_error: 0.2810 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2887 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6347 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.4920 - val_y1_output_root_mean_squared_error: 0.4001 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6889 - val_y2_output_accuracy: 0.0000e+00
# Epoch 482/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.2175 - y1_output_loss: 0.1018 - y2_output_loss: 0.1222 - y1_output_root_mean_squared_error: 0.3131 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3456 - y2_output_accuracy: 0.0000e+00 - val_loss: 1.9890 - val_y1_output_loss: 0.8430 - val_y2_output_loss: 1.1492 - val_y1_output_root_mean_squared_error: 0.9244 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 1.0651 - val_y2_output_accuracy: 0.0000e+00
# Epoch 483/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2002 - y1_output_loss: 0.0910 - y2_output_loss: 0.1083 - y1_output_root_mean_squared_error: 0.3028 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3295 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4981 - val_y1_output_loss: 0.1496 - val_y2_output_loss: 0.3638 - val_y1_output_root_mean_squared_error: 0.3924 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5866 - val_y2_output_accuracy: 0.0000e+00
# Epoch 484/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1835 - y1_output_loss: 0.0818 - y2_output_loss: 0.1007 - y1_output_root_mean_squared_error: 0.2865 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3184 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4701 - val_y1_output_loss: 0.1285 - val_y2_output_loss: 0.3532 - val_y1_output_root_mean_squared_error: 0.3639 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5811 - val_y2_output_accuracy: 0.0000e+00
# Epoch 485/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1449 - y1_output_loss: 0.0720 - y2_output_loss: 0.0760 - y1_output_root_mean_squared_error: 0.2669 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2715 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6593 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 0.5047 - val_y1_output_root_mean_squared_error: 0.4064 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7029 - val_y2_output_accuracy: 0.0000e+00
# Epoch 486/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1504 - y1_output_loss: 0.0741 - y2_output_loss: 0.0769 - y1_output_root_mean_squared_error: 0.2720 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2765 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5724 - val_y1_output_loss: 0.1940 - val_y2_output_loss: 0.3925 - val_y1_output_root_mean_squared_error: 0.4440 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6126 - val_y2_output_accuracy: 0.0000e+00
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.1573 - y1_output_loss: 0.0797 - y2_output_loss: 0.0767 - y1_output_root_mean_squared_error: 0.2829 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2780 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4374 - val_y1_output_loss: 0.1269 - val_y2_output_loss: 0.3228 - val_y1_output_root_mean_squared_error: 0.3601 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5547 - val_y2_output_accuracy: 0.0000e+00
# Epoch 488/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1543 - y1_output_loss: 0.0751 - y2_output_loss: 0.0807 - y1_output_root_mean_squared_error: 0.2728 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2827 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.7323 - val_y1_output_loss: 0.3027 - val_y2_output_loss: 0.4359 - val_y1_output_root_mean_squared_error: 0.5577 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6491 - val_y2_output_accuracy: 0.0000e+00
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4328 - y1_output_loss: 0.1369 - y2_output_loss: 0.2935 - y1_output_root_mean_squared_error: 0.3701 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.5439 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4731 - val_y1_output_loss: 0.1379 - val_y2_output_loss: 0.3452 - val_y1_output_root_mean_squared_error: 0.3772 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5752 - val_y2_output_accuracy: 0.0000e+00
# Epoch 490/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1242 - y1_output_loss: 0.0674 - y2_output_loss: 0.0569 - y1_output_root_mean_squared_error: 0.2605 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2372 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4504 - val_y1_output_loss: 0.1392 - val_y2_output_loss: 0.3260 - val_y1_output_root_mean_squared_error: 0.3770 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5552 - val_y2_output_accuracy: 0.0000e+00
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1642 - y1_output_loss: 0.0796 - y2_output_loss: 0.0865 - y1_output_root_mean_squared_error: 0.2795 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2934 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.9994 - val_y1_output_loss: 0.3330 - val_y2_output_loss: 0.6613 - val_y1_output_root_mean_squared_error: 0.5855 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.8103 - val_y2_output_accuracy: 0.0000e+00
# Epoch 492/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1495 - y1_output_loss: 0.0719 - y2_output_loss: 0.0768 - y1_output_root_mean_squared_error: 0.2688 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2780 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4493 - val_y1_output_loss: 0.1210 - val_y2_output_loss: 0.3432 - val_y1_output_root_mean_squared_error: 0.3519 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5705 - val_y2_output_accuracy: 0.0000e+00
# Epoch 493/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1480 - y1_output_loss: 0.0717 - y2_output_loss: 0.0750 - y1_output_root_mean_squared_error: 0.2689 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2751 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4277 - val_y1_output_loss: 0.1258 - val_y2_output_loss: 0.3165 - val_y1_output_root_mean_squared_error: 0.3598 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5461 - val_y2_output_accuracy: 0.0000e+00
# Epoch 494/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1443 - y1_output_loss: 0.0704 - y2_output_loss: 0.0734 - y1_output_root_mean_squared_error: 0.2664 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2709 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5058 - val_y1_output_loss: 0.1294 - val_y2_output_loss: 0.3831 - val_y1_output_root_mean_squared_error: 0.3642 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6109 - val_y2_output_accuracy: 0.0000e+00
# Epoch 495/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1668 - y1_output_loss: 0.0786 - y2_output_loss: 0.0886 - y1_output_root_mean_squared_error: 0.2804 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2970 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5629 - val_y1_output_loss: 0.1646 - val_y2_output_loss: 0.4162 - val_y1_output_root_mean_squared_error: 0.4082 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6295 - val_y2_output_accuracy: 0.0000e+00
# Epoch 496/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1565 - y1_output_loss: 0.0729 - y2_output_loss: 0.0839 - y1_output_root_mean_squared_error: 0.2708 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2884 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5063 - val_y1_output_loss: 0.1295 - val_y2_output_loss: 0.3821 - val_y1_output_root_mean_squared_error: 0.3661 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6102 - val_y2_output_accuracy: 0.0000e+00
# Epoch 497/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1535 - y1_output_loss: 0.0774 - y2_output_loss: 0.0789 - y1_output_root_mean_squared_error: 0.2760 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2781 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.8353 - val_y1_output_loss: 0.2283 - val_y2_output_loss: 0.6206 - val_y1_output_root_mean_squared_error: 0.4837 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.7755 - val_y2_output_accuracy: 0.0000e+00
# Epoch 498/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1754 - y1_output_loss: 0.0852 - y2_output_loss: 0.0902 - y1_output_root_mean_squared_error: 0.2918 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3004 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.4947 - val_y1_output_loss: 0.1675 - val_y2_output_loss: 0.3411 - val_y1_output_root_mean_squared_error: 0.4158 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.5673 - val_y2_output_accuracy: 0.0000e+00
# Epoch 499/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1764 - y1_output_loss: 0.0736 - y2_output_loss: 0.1018 - y1_output_root_mean_squared_error: 0.2722 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.3198 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.5445 - val_y1_output_loss: 0.1563 - val_y2_output_loss: 0.4040 - val_y1_output_root_mean_squared_error: 0.3988 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6209 - val_y2_output_accuracy: 0.0000e+00
# Epoch 500/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1321 - y1_output_loss: 0.0687 - y2_output_loss: 0.0646 - y1_output_root_mean_squared_error: 0.2594 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.2545 - y2_output_accuracy: 0.0000e+00 - val_loss: 0.6905 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.4418 - val_y1_output_root_mean_squared_error: 0.5151 - val_y1_output_accuracy: 0.0000e+00 - val_y2_output_root_mean_squared_error: 0.6520 - val_y2_output_accuracy: 0.0000e+00

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 0.6905 - y1_output_loss: 0.2718 - y2_output_loss: 0.4353 - y1_output_root_mean_squared_error: 0.5151 - y1_output_accuracy: 0.0000e+00 - y2_output_root_mean_squared_error: 0.6520 - y2_output_accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-bfeea1c4f0f2> in <module>
#       1 # Test the model and print loss and mse for both outputs
# ----> 2 loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
#       3 print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
#
# ValueError: too many values to unpack (expected 5)

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
