# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError(),
                      })

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 864us/sample - loss: 0.1319 - y1_output_loss: 0.0716 - y2_output_loss: 0.0607 - y1_output_root_mean_squared_error: 0.2669 - y2_output_root_mean_squared_error: 0.2462 - val_loss: 0.5177 - val_y1_output_loss: 0.1840 - val_y2_output_loss: 0.3519 - val_y1_output_root_mean_squared_error: 0.4322 - val_y2_output_root_mean_squared_error: 0.5752
# Epoch 2/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1648 - y1_output_loss: 0.0717 - y2_output_loss: 0.0938 - y1_output_root_mean_squared_error: 0.2668 - y2_output_root_mean_squared_error: 0.3060 - val_loss: 0.6170 - val_y1_output_loss: 0.1882 - val_y2_output_loss: 0.4401 - val_y1_output_root_mean_squared_error: 0.4404 - val_y2_output_root_mean_squared_error: 0.6504
# Epoch 3/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1468 - y1_output_loss: 0.0727 - y2_output_loss: 0.0729 - y1_output_root_mean_squared_error: 0.2708 - y2_output_root_mean_squared_error: 0.2712 - val_loss: 0.4631 - val_y1_output_loss: 0.1346 - val_y2_output_loss: 0.3533 - val_y1_output_root_mean_squared_error: 0.3701 - val_y2_output_root_mean_squared_error: 0.5710
# Epoch 4/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1673 - y1_output_loss: 0.0946 - y2_output_loss: 0.1024 - y1_output_root_mean_squared_error: 0.2915 - y2_output_root_mean_squared_error: 0.2869 - val_loss: 4.5599 - val_y1_output_loss: 0.6732 - val_y2_output_loss: 4.0148 - val_y1_output_root_mean_squared_error: 0.8271 - val_y2_output_root_mean_squared_error: 1.9687
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3612 - y1_output_loss: 0.1164 - y2_output_loss: 0.2421 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.4938 - val_loss: 0.5809 - val_y1_output_loss: 0.1503 - val_y2_output_loss: 0.4559 - val_y1_output_root_mean_squared_error: 0.3878 - val_y2_output_root_mean_squared_error: 0.6561
# Epoch 6/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.1621 - y1_output_loss: 0.0697 - y2_output_loss: 0.0921 - y1_output_root_mean_squared_error: 0.2648 - y2_output_root_mean_squared_error: 0.3033 - val_loss: 0.4538 - val_y1_output_loss: 0.1362 - val_y2_output_loss: 0.3337 - val_y1_output_root_mean_squared_error: 0.3727 - val_y2_output_root_mean_squared_error: 0.5612
# Epoch 7/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1615 - y1_output_loss: 0.0810 - y2_output_loss: 0.0814 - y1_output_root_mean_squared_error: 0.2832 - y2_output_root_mean_squared_error: 0.2851 - val_loss: 0.6419 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.4607 - val_y1_output_root_mean_squared_error: 0.4465 - val_y2_output_root_mean_squared_error: 0.6653
# Epoch 8/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2392 - y1_output_loss: 0.0967 - y2_output_loss: 0.1410 - y1_output_root_mean_squared_error: 0.3114 - y2_output_root_mean_squared_error: 0.3771 - val_loss: 0.5235 - val_y1_output_loss: 0.1719 - val_y2_output_loss: 0.3669 - val_y1_output_root_mean_squared_error: 0.4198 - val_y2_output_root_mean_squared_error: 0.5893
# Epoch 9/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2723 - y1_output_loss: 0.0969 - y2_output_loss: 0.1794 - y1_output_root_mean_squared_error: 0.3080 - y2_output_root_mean_squared_error: 0.4212 - val_loss: 1.3552 - val_y1_output_loss: 0.2989 - val_y2_output_loss: 1.0838 - val_y1_output_root_mean_squared_error: 0.5522 - val_y2_output_root_mean_squared_error: 1.0248
# Epoch 10/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.2047 - y1_output_loss: 0.0855 - y2_output_loss: 0.1257 - y1_output_root_mean_squared_error: 0.2839 - y2_output_root_mean_squared_error: 0.3523 - val_loss: 0.7548 - val_y1_output_loss: 0.2158 - val_y2_output_loss: 0.5445 - val_y1_output_root_mean_squared_error: 0.4697 - val_y2_output_root_mean_squared_error: 0.7309
# Epoch 11/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.2336 - y1_output_loss: 0.0840 - y2_output_loss: 0.1476 - y1_output_root_mean_squared_error: 0.2910 - y2_output_root_mean_squared_error: 0.3858 - val_loss: 0.4513 - val_y1_output_loss: 0.1356 - val_y2_output_loss: 0.3392 - val_y1_output_root_mean_squared_error: 0.3714 - val_y2_output_root_mean_squared_error: 0.5598
# Epoch 12/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1696 - y1_output_loss: 0.0732 - y2_output_loss: 0.0953 - y1_output_root_mean_squared_error: 0.2713 - y2_output_root_mean_squared_error: 0.3098 - val_loss: 0.4666 - val_y1_output_loss: 0.1365 - val_y2_output_loss: 0.3415 - val_y1_output_root_mean_squared_error: 0.3751 - val_y2_output_root_mean_squared_error: 0.5709
# Epoch 13/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1540 - y1_output_loss: 0.0807 - y2_output_loss: 0.0730 - y1_output_root_mean_squared_error: 0.2851 - y2_output_root_mean_squared_error: 0.2697 - val_loss: 0.4835 - val_y1_output_loss: 0.1276 - val_y2_output_loss: 0.3722 - val_y1_output_root_mean_squared_error: 0.3605 - val_y2_output_root_mean_squared_error: 0.5946
# Epoch 14/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1290 - y1_output_loss: 0.0681 - y2_output_loss: 0.0608 - y1_output_root_mean_squared_error: 0.2604 - y2_output_root_mean_squared_error: 0.2474 - val_loss: 0.4373 - val_y1_output_loss: 0.1312 - val_y2_output_loss: 0.3222 - val_y1_output_root_mean_squared_error: 0.3658 - val_y2_output_root_mean_squared_error: 0.5509
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1675 - y1_output_loss: 0.0809 - y2_output_loss: 0.0857 - y1_output_root_mean_squared_error: 0.2853 - y2_output_root_mean_squared_error: 0.2935 - val_loss: 0.4510 - val_y1_output_loss: 0.1347 - val_y2_output_loss: 0.3309 - val_y1_output_root_mean_squared_error: 0.3720 - val_y2_output_root_mean_squared_error: 0.5591
# Epoch 16/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1429 - y1_output_loss: 0.0684 - y2_output_loss: 0.0744 - y1_output_root_mean_squared_error: 0.2620 - y2_output_root_mean_squared_error: 0.2725 - val_loss: 0.8107 - val_y1_output_loss: 0.1737 - val_y2_output_loss: 0.6477 - val_y1_output_root_mean_squared_error: 0.4240 - val_y2_output_root_mean_squared_error: 0.7943
# Epoch 17/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1426 - y1_output_loss: 0.0690 - y2_output_loss: 0.0739 - y1_output_root_mean_squared_error: 0.2609 - y2_output_root_mean_squared_error: 0.2729 - val_loss: 0.4861 - val_y1_output_loss: 0.1492 - val_y2_output_loss: 0.3497 - val_y1_output_root_mean_squared_error: 0.3898 - val_y2_output_root_mean_squared_error: 0.5781
# Epoch 18/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1471 - y1_output_loss: 0.0706 - y2_output_loss: 0.0751 - y1_output_root_mean_squared_error: 0.2670 - y2_output_root_mean_squared_error: 0.2753 - val_loss: 0.4651 - val_y1_output_loss: 0.1395 - val_y2_output_loss: 0.3423 - val_y1_output_root_mean_squared_error: 0.3771 - val_y2_output_root_mean_squared_error: 0.5682
# Epoch 19/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1723 - y1_output_loss: 0.0825 - y2_output_loss: 0.0885 - y1_output_root_mean_squared_error: 0.2886 - y2_output_root_mean_squared_error: 0.2984 - val_loss: 0.4460 - val_y1_output_loss: 0.1310 - val_y2_output_loss: 0.3376 - val_y1_output_root_mean_squared_error: 0.3651 - val_y2_output_root_mean_squared_error: 0.5592
# Epoch 20/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.1790 - y1_output_loss: 0.0799 - y2_output_loss: 0.0986 - y1_output_root_mean_squared_error: 0.2834 - y2_output_root_mean_squared_error: 0.3141 - val_loss: 0.5173 - val_y1_output_loss: 0.1399 - val_y2_output_loss: 0.3976 - val_y1_output_root_mean_squared_error: 0.3765 - val_y2_output_root_mean_squared_error: 0.6129
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1531 - y1_output_loss: 0.0748 - y2_output_loss: 0.0775 - y1_output_root_mean_squared_error: 0.2735 - y2_output_root_mean_squared_error: 0.2797 - val_loss: 0.4871 - val_y1_output_loss: 0.1649 - val_y2_output_loss: 0.3311 - val_y1_output_root_mean_squared_error: 0.4100 - val_y2_output_root_mean_squared_error: 0.5648
# Epoch 22/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.1671 - y1_output_loss: 0.0747 - y2_output_loss: 0.0914 - y1_output_root_mean_squared_error: 0.2738 - y2_output_root_mean_squared_error: 0.3036 - val_loss: 0.5663 - val_y1_output_loss: 0.1741 - val_y2_output_loss: 0.4059 - val_y1_output_root_mean_squared_error: 0.4241 - val_y2_output_root_mean_squared_error: 0.6216
# Epoch 23/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2519 - y1_output_loss: 0.0851 - y2_output_loss: 0.1672 - y1_output_root_mean_squared_error: 0.2903 - y2_output_root_mean_squared_error: 0.4095 - val_loss: 0.9747 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.7615 - val_y1_output_root_mean_squared_error: 0.5073 - val_y2_output_root_mean_squared_error: 0.8470
# Epoch 24/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2017 - y1_output_loss: 0.0871 - y2_output_loss: 0.1130 - y1_output_root_mean_squared_error: 0.2964 - y2_output_root_mean_squared_error: 0.3374 - val_loss: 0.4388 - val_y1_output_loss: 0.1286 - val_y2_output_loss: 0.3337 - val_y1_output_root_mean_squared_error: 0.3598 - val_y2_output_root_mean_squared_error: 0.5562
# Epoch 25/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2022 - y1_output_loss: 0.0857 - y2_output_loss: 0.1153 - y1_output_root_mean_squared_error: 0.2939 - y2_output_root_mean_squared_error: 0.3403 - val_loss: 0.5137 - val_y1_output_loss: 0.1300 - val_y2_output_loss: 0.4032 - val_y1_output_root_mean_squared_error: 0.3650 - val_y2_output_root_mean_squared_error: 0.6168
# Epoch 26/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1416 - y1_output_loss: 0.0713 - y2_output_loss: 0.0695 - y1_output_root_mean_squared_error: 0.2678 - y2_output_root_mean_squared_error: 0.2643 - val_loss: 0.4442 - val_y1_output_loss: 0.1366 - val_y2_output_loss: 0.3266 - val_y1_output_root_mean_squared_error: 0.3745 - val_y2_output_root_mean_squared_error: 0.5513
# Epoch 27/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1856 - y1_output_loss: 0.0777 - y2_output_loss: 0.1084 - y1_output_root_mean_squared_error: 0.2777 - y2_output_root_mean_squared_error: 0.3294 - val_loss: 0.5748 - val_y1_output_loss: 0.2072 - val_y2_output_loss: 0.3840 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 0.6019
# Epoch 28/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.1735 - y1_output_loss: 0.0861 - y2_output_loss: 0.0872 - y1_output_root_mean_squared_error: 0.2936 - y2_output_root_mean_squared_error: 0.2954 - val_loss: 0.5522 - val_y1_output_loss: 0.1677 - val_y2_output_loss: 0.3944 - val_y1_output_root_mean_squared_error: 0.4136 - val_y2_output_root_mean_squared_error: 0.6173
# Epoch 29/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.1724 - y1_output_loss: 0.0740 - y2_output_loss: 0.0973 - y1_output_root_mean_squared_error: 0.2725 - y2_output_root_mean_squared_error: 0.3133 - val_loss: 0.4831 - val_y1_output_loss: 0.1328 - val_y2_output_loss: 0.3637 - val_y1_output_root_mean_squared_error: 0.3696 - val_y2_output_root_mean_squared_error: 0.5886
# Epoch 30/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1303 - y1_output_loss: 0.0697 - y2_output_loss: 0.0604 - y1_output_root_mean_squared_error: 0.2641 - y2_output_root_mean_squared_error: 0.2461 - val_loss: 0.5219 - val_y1_output_loss: 0.1505 - val_y2_output_loss: 0.3825 - val_y1_output_root_mean_squared_error: 0.3920 - val_y2_output_root_mean_squared_error: 0.6068
# Epoch 31/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1490 - y1_output_loss: 0.0698 - y2_output_loss: 0.0785 - y1_output_root_mean_squared_error: 0.2649 - y2_output_root_mean_squared_error: 0.2808 - val_loss: 0.5170 - val_y1_output_loss: 0.1436 - val_y2_output_loss: 0.3953 - val_y1_output_root_mean_squared_error: 0.3804 - val_y2_output_root_mean_squared_error: 0.6101
# Epoch 32/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1438 - y1_output_loss: 0.0738 - y2_output_loss: 0.0690 - y1_output_root_mean_squared_error: 0.2728 - y2_output_root_mean_squared_error: 0.2634 - val_loss: 0.4575 - val_y1_output_loss: 0.1282 - val_y2_output_loss: 0.3469 - val_y1_output_root_mean_squared_error: 0.3623 - val_y2_output_root_mean_squared_error: 0.5712
# Epoch 33/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1528 - y1_output_loss: 0.0778 - y2_output_loss: 0.0750 - y1_output_root_mean_squared_error: 0.2782 - y2_output_root_mean_squared_error: 0.2745 - val_loss: 0.5206 - val_y1_output_loss: 0.2008 - val_y2_output_loss: 0.3259 - val_y1_output_root_mean_squared_error: 0.4546 - val_y2_output_root_mean_squared_error: 0.5603
# Epoch 34/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2176 - y1_output_loss: 0.0844 - y2_output_loss: 0.1315 - y1_output_root_mean_squared_error: 0.2917 - y2_output_root_mean_squared_error: 0.3640 - val_loss: 0.4618 - val_y1_output_loss: 0.1577 - val_y2_output_loss: 0.3155 - val_y1_output_root_mean_squared_error: 0.3997 - val_y2_output_root_mean_squared_error: 0.5496
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1520 - y1_output_loss: 0.0776 - y2_output_loss: 0.0733 - y1_output_root_mean_squared_error: 0.2798 - y2_output_root_mean_squared_error: 0.2715 - val_loss: 0.4343 - val_y1_output_loss: 0.1328 - val_y2_output_loss: 0.3185 - val_y1_output_root_mean_squared_error: 0.3690 - val_y2_output_root_mean_squared_error: 0.5461
# Epoch 36/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1559 - y1_output_loss: 0.0777 - y2_output_loss: 0.0776 - y1_output_root_mean_squared_error: 0.2798 - y2_output_root_mean_squared_error: 0.2785 - val_loss: 0.4933 - val_y1_output_loss: 0.1432 - val_y2_output_loss: 0.3712 - val_y1_output_root_mean_squared_error: 0.3803 - val_y2_output_root_mean_squared_error: 0.5905
# Epoch 37/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1307 - y1_output_loss: 0.0691 - y2_output_loss: 0.0635 - y1_output_root_mean_squared_error: 0.2606 - y2_output_root_mean_squared_error: 0.2506 - val_loss: 0.6296 - val_y1_output_loss: 0.1863 - val_y2_output_loss: 0.4572 - val_y1_output_root_mean_squared_error: 0.4349 - val_y2_output_root_mean_squared_error: 0.6636
# Epoch 38/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1624 - y1_output_loss: 0.0785 - y2_output_loss: 0.0835 - y1_output_root_mean_squared_error: 0.2800 - y2_output_root_mean_squared_error: 0.2899 - val_loss: 0.4515 - val_y1_output_loss: 0.1378 - val_y2_output_loss: 0.3277 - val_y1_output_root_mean_squared_error: 0.3748 - val_y2_output_root_mean_squared_error: 0.5577
# Epoch 39/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1802 - y1_output_loss: 0.0764 - y2_output_loss: 0.1030 - y1_output_root_mean_squared_error: 0.2777 - y2_output_root_mean_squared_error: 0.3210 - val_loss: 0.5370 - val_y1_output_loss: 0.1522 - val_y2_output_loss: 0.4133 - val_y1_output_root_mean_squared_error: 0.3907 - val_y2_output_root_mean_squared_error: 0.6200
# Epoch 40/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1408 - y1_output_loss: 0.0690 - y2_output_loss: 0.0755 - y1_output_root_mean_squared_error: 0.2635 - y2_output_root_mean_squared_error: 0.2671 - val_loss: 0.5601 - val_y1_output_loss: 0.1435 - val_y2_output_loss: 0.4511 - val_y1_output_root_mean_squared_error: 0.3802 - val_y2_output_root_mean_squared_error: 0.6446
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3265 - y1_output_loss: 0.1027 - y2_output_loss: 0.2216 - y1_output_root_mean_squared_error: 0.3212 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 0.4246 - val_y1_output_loss: 0.1290 - val_y2_output_loss: 0.3122 - val_y1_output_root_mean_squared_error: 0.3609 - val_y2_output_root_mean_squared_error: 0.5425
# Epoch 42/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1684 - y1_output_loss: 0.0830 - y2_output_loss: 0.0844 - y1_output_root_mean_squared_error: 0.2892 - y2_output_root_mean_squared_error: 0.2911 - val_loss: 0.4942 - val_y1_output_loss: 0.1458 - val_y2_output_loss: 0.3656 - val_y1_output_root_mean_squared_error: 0.3864 - val_y2_output_root_mean_squared_error: 0.5873
# Epoch 43/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1812 - y1_output_loss: 0.0767 - y2_output_loss: 0.1067 - y1_output_root_mean_squared_error: 0.2736 - y2_output_root_mean_squared_error: 0.3261 - val_loss: 1.0087 - val_y1_output_loss: 0.4822 - val_y2_output_loss: 0.5499 - val_y1_output_root_mean_squared_error: 0.6943 - val_y2_output_root_mean_squared_error: 0.7257
# Epoch 44/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3332 - y1_output_loss: 0.1187 - y2_output_loss: 0.2119 - y1_output_root_mean_squared_error: 0.3458 - y2_output_root_mean_squared_error: 0.4621 - val_loss: 0.4952 - val_y1_output_loss: 0.1355 - val_y2_output_loss: 0.3727 - val_y1_output_root_mean_squared_error: 0.3722 - val_y2_output_root_mean_squared_error: 0.5972
# Epoch 45/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1705 - y1_output_loss: 0.0742 - y2_output_loss: 0.0961 - y1_output_root_mean_squared_error: 0.2733 - y2_output_root_mean_squared_error: 0.3096 - val_loss: 0.5247 - val_y1_output_loss: 0.1492 - val_y2_output_loss: 0.4034 - val_y1_output_root_mean_squared_error: 0.3877 - val_y2_output_root_mean_squared_error: 0.6119
# Epoch 46/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.1717 - y1_output_loss: 0.0912 - y2_output_loss: 0.0852 - y1_output_root_mean_squared_error: 0.3011 - y2_output_root_mean_squared_error: 0.2848 - val_loss: 1.2585 - val_y1_output_loss: 0.6019 - val_y2_output_loss: 0.6666 - val_y1_output_root_mean_squared_error: 0.7797 - val_y2_output_root_mean_squared_error: 0.8066
# Epoch 47/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1939 - y1_output_loss: 0.0967 - y2_output_loss: 0.0962 - y1_output_root_mean_squared_error: 0.3122 - y2_output_root_mean_squared_error: 0.3105 - val_loss: 0.5216 - val_y1_output_loss: 0.1332 - val_y2_output_loss: 0.3949 - val_y1_output_root_mean_squared_error: 0.3708 - val_y2_output_root_mean_squared_error: 0.6198
# Epoch 48/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.1759 - y1_output_loss: 0.0836 - y2_output_loss: 0.0916 - y1_output_root_mean_squared_error: 0.2899 - y2_output_root_mean_squared_error: 0.3031 - val_loss: 0.4559 - val_y1_output_loss: 0.1492 - val_y2_output_loss: 0.3256 - val_y1_output_root_mean_squared_error: 0.3919 - val_y2_output_root_mean_squared_error: 0.5499
# Epoch 49/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1258 - y1_output_loss: 0.0677 - y2_output_loss: 0.0587 - y1_output_root_mean_squared_error: 0.2599 - y2_output_root_mean_squared_error: 0.2414 - val_loss: 0.5823 - val_y1_output_loss: 0.1497 - val_y2_output_loss: 0.4440 - val_y1_output_root_mean_squared_error: 0.3915 - val_y2_output_root_mean_squared_error: 0.6550
# Epoch 50/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1628 - y1_output_loss: 0.0698 - y2_output_loss: 0.0919 - y1_output_root_mean_squared_error: 0.2647 - y2_output_root_mean_squared_error: 0.3045 - val_loss: 0.4553 - val_y1_output_loss: 0.1373 - val_y2_output_loss: 0.3315 - val_y1_output_root_mean_squared_error: 0.3746 - val_y2_output_root_mean_squared_error: 0.5612
# Epoch 51/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1225 - y1_output_loss: 0.0693 - y2_output_loss: 0.0574 - y1_output_root_mean_squared_error: 0.2574 - y2_output_root_mean_squared_error: 0.2372 - val_loss: 1.7387 - val_y1_output_loss: 0.8781 - val_y2_output_loss: 0.8817 - val_y1_output_root_mean_squared_error: 0.9397 - val_y2_output_root_mean_squared_error: 0.9250
# Epoch 52/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2700 - y1_output_loss: 0.1173 - y2_output_loss: 0.1522 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.3906 - val_loss: 0.7717 - val_y1_output_loss: 0.2446 - val_y2_output_loss: 0.5258 - val_y1_output_root_mean_squared_error: 0.4989 - val_y2_output_root_mean_squared_error: 0.7230
# Epoch 53/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.1909 - y1_output_loss: 0.0801 - y2_output_loss: 0.1094 - y1_output_root_mean_squared_error: 0.2839 - y2_output_root_mean_squared_error: 0.3321 - val_loss: 0.4502 - val_y1_output_loss: 0.1438 - val_y2_output_loss: 0.3267 - val_y1_output_root_mean_squared_error: 0.3821 - val_y2_output_root_mean_squared_error: 0.5516
# Epoch 54/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1316 - y1_output_loss: 0.0688 - y2_output_loss: 0.0646 - y1_output_root_mean_squared_error: 0.2611 - y2_output_root_mean_squared_error: 0.2518 - val_loss: 0.7025 - val_y1_output_loss: 0.2057 - val_y2_output_loss: 0.5020 - val_y1_output_root_mean_squared_error: 0.4604 - val_y2_output_root_mean_squared_error: 0.7004
# Epoch 55/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3167 - y1_output_loss: 0.0968 - y2_output_loss: 0.2172 - y1_output_root_mean_squared_error: 0.3123 - y2_output_root_mean_squared_error: 0.4681 - val_loss: 0.4678 - val_y1_output_loss: 0.1480 - val_y2_output_loss: 0.3315 - val_y1_output_root_mean_squared_error: 0.3879 - val_y2_output_root_mean_squared_error: 0.5633
# Epoch 56/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1453 - y1_output_loss: 0.0738 - y2_output_loss: 0.0709 - y1_output_root_mean_squared_error: 0.2724 - y2_output_root_mean_squared_error: 0.2666 - val_loss: 0.4821 - val_y1_output_loss: 0.1347 - val_y2_output_loss: 0.3582 - val_y1_output_root_mean_squared_error: 0.3704 - val_y2_output_root_mean_squared_error: 0.5872
# Epoch 57/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1567 - y1_output_loss: 0.0809 - y2_output_loss: 0.0747 - y1_output_root_mean_squared_error: 0.2854 - y2_output_root_mean_squared_error: 0.2743 - val_loss: 0.5064 - val_y1_output_loss: 0.1540 - val_y2_output_loss: 0.3601 - val_y1_output_root_mean_squared_error: 0.3979 - val_y2_output_root_mean_squared_error: 0.5900
# Epoch 58/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1670 - y1_output_loss: 0.0761 - y2_output_loss: 0.0900 - y1_output_root_mean_squared_error: 0.2768 - y2_output_root_mean_squared_error: 0.3006 - val_loss: 0.5017 - val_y1_output_loss: 0.1508 - val_y2_output_loss: 0.3546 - val_y1_output_root_mean_squared_error: 0.3937 - val_y2_output_root_mean_squared_error: 0.5888
# Epoch 59/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1515 - y1_output_loss: 0.0751 - y2_output_loss: 0.0760 - y1_output_root_mean_squared_error: 0.2751 - y2_output_root_mean_squared_error: 0.2754 - val_loss: 0.5569 - val_y1_output_loss: 0.1455 - val_y2_output_loss: 0.4184 - val_y1_output_root_mean_squared_error: 0.3879 - val_y2_output_root_mean_squared_error: 0.6376
# Epoch 60/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.1516 - y1_output_loss: 0.0732 - y2_output_loss: 0.0776 - y1_output_root_mean_squared_error: 0.2712 - y2_output_root_mean_squared_error: 0.2793 - val_loss: 0.5604 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.4091 - val_y1_output_root_mean_squared_error: 0.4170 - val_y2_output_root_mean_squared_error: 0.6217
# Epoch 61/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1352 - y1_output_loss: 0.0690 - y2_output_loss: 0.0658 - y1_output_root_mean_squared_error: 0.2633 - y2_output_root_mean_squared_error: 0.2568 - val_loss: 0.4740 - val_y1_output_loss: 0.1433 - val_y2_output_loss: 0.3430 - val_y1_output_root_mean_squared_error: 0.3830 - val_y2_output_root_mean_squared_error: 0.5721
# Epoch 62/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1397 - y1_output_loss: 0.0677 - y2_output_loss: 0.0720 - y1_output_root_mean_squared_error: 0.2609 - y2_output_root_mean_squared_error: 0.2675 - val_loss: 0.5033 - val_y1_output_loss: 0.1500 - val_y2_output_loss: 0.3595 - val_y1_output_root_mean_squared_error: 0.3939 - val_y2_output_root_mean_squared_error: 0.5901
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1469 - y1_output_loss: 0.0777 - y2_output_loss: 0.0689 - y1_output_root_mean_squared_error: 0.2785 - y2_output_root_mean_squared_error: 0.2634 - val_loss: 0.6303 - val_y1_output_loss: 0.2498 - val_y2_output_loss: 0.3867 - val_y1_output_root_mean_squared_error: 0.5048 - val_y2_output_root_mean_squared_error: 0.6127
# Epoch 64/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2186 - y1_output_loss: 0.0777 - y2_output_loss: 0.1394 - y1_output_root_mean_squared_error: 0.2796 - y2_output_root_mean_squared_error: 0.3748 - val_loss: 0.4745 - val_y1_output_loss: 0.1652 - val_y2_output_loss: 0.3216 - val_y1_output_root_mean_squared_error: 0.4082 - val_y2_output_root_mean_squared_error: 0.5549
# Epoch 65/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1467 - y1_output_loss: 0.0724 - y2_output_loss: 0.0743 - y1_output_root_mean_squared_error: 0.2682 - y2_output_root_mean_squared_error: 0.2734 - val_loss: 0.4569 - val_y1_output_loss: 0.1579 - val_y2_output_loss: 0.3082 - val_y1_output_root_mean_squared_error: 0.4033 - val_y2_output_root_mean_squared_error: 0.5424
# Epoch 66/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1442 - y1_output_loss: 0.0772 - y2_output_loss: 0.0732 - y1_output_root_mean_squared_error: 0.2702 - y2_output_root_mean_squared_error: 0.2667 - val_loss: 2.4285 - val_y1_output_loss: 1.2363 - val_y2_output_loss: 1.1914 - val_y1_output_root_mean_squared_error: 1.1174 - val_y2_output_root_mean_squared_error: 1.0863
# Epoch 67/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1909 - y1_output_loss: 0.0928 - y2_output_loss: 0.0973 - y1_output_root_mean_squared_error: 0.3056 - y2_output_root_mean_squared_error: 0.3123 - val_loss: 0.4922 - val_y1_output_loss: 0.1330 - val_y2_output_loss: 0.3756 - val_y1_output_root_mean_squared_error: 0.3687 - val_y2_output_root_mean_squared_error: 0.5969
# Epoch 68/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2396 - y1_output_loss: 0.0859 - y2_output_loss: 0.1517 - y1_output_root_mean_squared_error: 0.2942 - y2_output_root_mean_squared_error: 0.3913 - val_loss: 0.4392 - val_y1_output_loss: 0.1274 - val_y2_output_loss: 0.3211 - val_y1_output_root_mean_squared_error: 0.3623 - val_y2_output_root_mean_squared_error: 0.5550
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1520 - y1_output_loss: 0.0736 - y2_output_loss: 0.0783 - y1_output_root_mean_squared_error: 0.2715 - y2_output_root_mean_squared_error: 0.2799 - val_loss: 0.5261 - val_y1_output_loss: 0.1523 - val_y2_output_loss: 0.3912 - val_y1_output_root_mean_squared_error: 0.3939 - val_y2_output_root_mean_squared_error: 0.6090
# Epoch 70/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1576 - y1_output_loss: 0.0686 - y2_output_loss: 0.0895 - y1_output_root_mean_squared_error: 0.2623 - y2_output_root_mean_squared_error: 0.2980 - val_loss: 0.5035 - val_y1_output_loss: 0.1647 - val_y2_output_loss: 0.3540 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 0.5823
# Epoch 71/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1509 - y1_output_loss: 0.0714 - y2_output_loss: 0.0783 - y1_output_root_mean_squared_error: 0.2682 - y2_output_root_mean_squared_error: 0.2810 - val_loss: 0.4439 - val_y1_output_loss: 0.1291 - val_y2_output_loss: 0.3272 - val_y1_output_root_mean_squared_error: 0.3641 - val_y2_output_root_mean_squared_error: 0.5579
# Epoch 72/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.1600 - y1_output_loss: 0.0756 - y2_output_loss: 0.0832 - y1_output_root_mean_squared_error: 0.2758 - y2_output_root_mean_squared_error: 0.2897 - val_loss: 0.4924 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.3230 - val_y1_output_root_mean_squared_error: 0.4293 - val_y2_output_root_mean_squared_error: 0.5551
# Epoch 73/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.1326 - y1_output_loss: 0.0679 - y2_output_loss: 0.0650 - y1_output_root_mean_squared_error: 0.2608 - y2_output_root_mean_squared_error: 0.2542 - val_loss: 0.5157 - val_y1_output_loss: 0.1375 - val_y2_output_loss: 0.3857 - val_y1_output_root_mean_squared_error: 0.3753 - val_y2_output_root_mean_squared_error: 0.6122
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1373 - y1_output_loss: 0.0654 - y2_output_loss: 0.0709 - y1_output_root_mean_squared_error: 0.2564 - y2_output_root_mean_squared_error: 0.2676 - val_loss: 0.4860 - val_y1_output_loss: 0.1429 - val_y2_output_loss: 0.3679 - val_y1_output_root_mean_squared_error: 0.3804 - val_y2_output_root_mean_squared_error: 0.5842
# Epoch 75/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1300 - y1_output_loss: 0.0663 - y2_output_loss: 0.0635 - y1_output_root_mean_squared_error: 0.2579 - y2_output_root_mean_squared_error: 0.2521 - val_loss: 0.4246 - val_y1_output_loss: 0.1289 - val_y2_output_loss: 0.3157 - val_y1_output_root_mean_squared_error: 0.3623 - val_y2_output_root_mean_squared_error: 0.5416
# Epoch 76/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1720 - y1_output_loss: 0.0763 - y2_output_loss: 0.0950 - y1_output_root_mean_squared_error: 0.2768 - y2_output_root_mean_squared_error: 0.3088 - val_loss: 0.4973 - val_y1_output_loss: 0.1463 - val_y2_output_loss: 0.3741 - val_y1_output_root_mean_squared_error: 0.3838 - val_y2_output_root_mean_squared_error: 0.5916
# Epoch 77/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1506 - y1_output_loss: 0.0716 - y2_output_loss: 0.0778 - y1_output_root_mean_squared_error: 0.2687 - y2_output_root_mean_squared_error: 0.2799 - val_loss: 0.4325 - val_y1_output_loss: 0.1321 - val_y2_output_loss: 0.3169 - val_y1_output_root_mean_squared_error: 0.3659 - val_y2_output_root_mean_squared_error: 0.5464
# Epoch 78/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.1255 - y1_output_loss: 0.0701 - y2_output_loss: 0.0558 - y1_output_root_mean_squared_error: 0.2641 - y2_output_root_mean_squared_error: 0.2363 - val_loss: 0.5316 - val_y1_output_loss: 0.1699 - val_y2_output_loss: 0.3762 - val_y1_output_root_mean_squared_error: 0.4139 - val_y2_output_root_mean_squared_error: 0.6002
# Epoch 79/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1997 - y1_output_loss: 0.0944 - y2_output_loss: 0.1061 - y1_output_root_mean_squared_error: 0.3060 - y2_output_root_mean_squared_error: 0.3258 - val_loss: 0.6004 - val_y1_output_loss: 0.1796 - val_y2_output_loss: 0.4268 - val_y1_output_root_mean_squared_error: 0.4300 - val_y2_output_root_mean_squared_error: 0.6446
# Epoch 80/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1230 - y1_output_loss: 0.0650 - y2_output_loss: 0.0584 - y1_output_root_mean_squared_error: 0.2551 - y2_output_root_mean_squared_error: 0.2406 - val_loss: 0.5804 - val_y1_output_loss: 0.1617 - val_y2_output_loss: 0.4276 - val_y1_output_root_mean_squared_error: 0.4066 - val_y2_output_root_mean_squared_error: 0.6443
# Epoch 81/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2296 - y1_output_loss: 0.0941 - y2_output_loss: 0.1422 - y1_output_root_mean_squared_error: 0.2938 - y2_output_root_mean_squared_error: 0.3785 - val_loss: 0.6228 - val_y1_output_loss: 0.2626 - val_y2_output_loss: 0.3751 - val_y1_output_root_mean_squared_error: 0.5157 - val_y2_output_root_mean_squared_error: 0.5974
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2352 - y1_output_loss: 0.0855 - y2_output_loss: 0.1503 - y1_output_root_mean_squared_error: 0.2924 - y2_output_root_mean_squared_error: 0.3869 - val_loss: 0.5651 - val_y1_output_loss: 0.1631 - val_y2_output_loss: 0.4087 - val_y1_output_root_mean_squared_error: 0.4096 - val_y2_output_root_mean_squared_error: 0.6304
# Epoch 83/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1856 - y1_output_loss: 0.0855 - y2_output_loss: 0.0993 - y1_output_root_mean_squared_error: 0.2929 - y2_output_root_mean_squared_error: 0.3158 - val_loss: 0.4557 - val_y1_output_loss: 0.1385 - val_y2_output_loss: 0.3372 - val_y1_output_root_mean_squared_error: 0.3729 - val_y2_output_root_mean_squared_error: 0.5627
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1302 - y1_output_loss: 0.0648 - y2_output_loss: 0.0652 - y1_output_root_mean_squared_error: 0.2554 - y2_output_root_mean_squared_error: 0.2549 - val_loss: 0.4621 - val_y1_output_loss: 0.1317 - val_y2_output_loss: 0.3424 - val_y1_output_root_mean_squared_error: 0.3671 - val_y2_output_root_mean_squared_error: 0.5722
# Epoch 85/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2060 - y1_output_loss: 0.0942 - y2_output_loss: 0.1131 - y1_output_root_mean_squared_error: 0.3073 - y2_output_root_mean_squared_error: 0.3341 - val_loss: 0.6226 - val_y1_output_loss: 0.1665 - val_y2_output_loss: 0.4692 - val_y1_output_root_mean_squared_error: 0.4128 - val_y2_output_root_mean_squared_error: 0.6725
# Epoch 86/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1310 - y1_output_loss: 0.0688 - y2_output_loss: 0.0630 - y1_output_root_mean_squared_error: 0.2606 - y2_output_root_mean_squared_error: 0.2512 - val_loss: 0.6113 - val_y1_output_loss: 0.3023 - val_y2_output_loss: 0.3266 - val_y1_output_root_mean_squared_error: 0.5486 - val_y2_output_root_mean_squared_error: 0.5571
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1474 - y1_output_loss: 0.0761 - y2_output_loss: 0.0701 - y1_output_root_mean_squared_error: 0.2771 - y2_output_root_mean_squared_error: 0.2658 - val_loss: 0.4341 - val_y1_output_loss: 0.1334 - val_y2_output_loss: 0.3100 - val_y1_output_root_mean_squared_error: 0.3691 - val_y2_output_root_mean_squared_error: 0.5457
# Epoch 88/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1505 - y1_output_loss: 0.0670 - y2_output_loss: 0.0828 - y1_output_root_mean_squared_error: 0.2591 - y2_output_root_mean_squared_error: 0.2888 - val_loss: 0.4477 - val_y1_output_loss: 0.1477 - val_y2_output_loss: 0.3092 - val_y1_output_root_mean_squared_error: 0.3858 - val_y2_output_root_mean_squared_error: 0.5467
# Epoch 89/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.1938 - y1_output_loss: 0.0901 - y2_output_loss: 0.1022 - y1_output_root_mean_squared_error: 0.3013 - y2_output_root_mean_squared_error: 0.3210 - val_loss: 0.4484 - val_y1_output_loss: 0.1454 - val_y2_output_loss: 0.3131 - val_y1_output_root_mean_squared_error: 0.3862 - val_y2_output_root_mean_squared_error: 0.5470
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1254 - y1_output_loss: 0.0683 - y2_output_loss: 0.0592 - y1_output_root_mean_squared_error: 0.2602 - y2_output_root_mean_squared_error: 0.2402 - val_loss: 0.8812 - val_y1_output_loss: 0.2397 - val_y2_output_loss: 0.6396 - val_y1_output_root_mean_squared_error: 0.4978 - val_y2_output_root_mean_squared_error: 0.7958
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1494 - y1_output_loss: 0.0728 - y2_output_loss: 0.0767 - y1_output_root_mean_squared_error: 0.2697 - y2_output_root_mean_squared_error: 0.2769 - val_loss: 0.5732 - val_y1_output_loss: 0.1438 - val_y2_output_loss: 0.4493 - val_y1_output_root_mean_squared_error: 0.3818 - val_y2_output_root_mean_squared_error: 0.6538
# Epoch 92/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1729 - y1_output_loss: 0.0778 - y2_output_loss: 0.0994 - y1_output_root_mean_squared_error: 0.2734 - y2_output_root_mean_squared_error: 0.3133 - val_loss: 2.9219 - val_y1_output_loss: 1.2327 - val_y2_output_loss: 1.7176 - val_y1_output_root_mean_squared_error: 1.1139 - val_y2_output_root_mean_squared_error: 1.2966
# Epoch 93/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.2034 - y1_output_loss: 0.0885 - y2_output_loss: 0.1138 - y1_output_root_mean_squared_error: 0.2986 - y2_output_root_mean_squared_error: 0.3379 - val_loss: 0.4209 - val_y1_output_loss: 0.1277 - val_y2_output_loss: 0.3102 - val_y1_output_root_mean_squared_error: 0.3602 - val_y2_output_root_mean_squared_error: 0.5395
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.1235 - y1_output_loss: 0.0692 - y2_output_loss: 0.0587 - y1_output_root_mean_squared_error: 0.2578 - y2_output_root_mean_squared_error: 0.2389 - val_loss: 1.1630 - val_y1_output_loss: 0.4710 - val_y2_output_loss: 0.7171 - val_y1_output_root_mean_squared_error: 0.6876 - val_y2_output_root_mean_squared_error: 0.8308
# Epoch 95/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1485 - y1_output_loss: 0.0724 - y2_output_loss: 0.0750 - y1_output_root_mean_squared_error: 0.2703 - y2_output_root_mean_squared_error: 0.2747 - val_loss: 0.4565 - val_y1_output_loss: 0.1453 - val_y2_output_loss: 0.3220 - val_y1_output_root_mean_squared_error: 0.3851 - val_y2_output_root_mean_squared_error: 0.5552
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.1553 - y1_output_loss: 0.0740 - y2_output_loss: 0.0843 - y1_output_root_mean_squared_error: 0.2712 - y2_output_root_mean_squared_error: 0.2859 - val_loss: 0.7257 - val_y1_output_loss: 0.1612 - val_y2_output_loss: 0.5771 - val_y1_output_root_mean_squared_error: 0.4069 - val_y2_output_root_mean_squared_error: 0.7484
# Epoch 97/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.1278 - y1_output_loss: 0.0632 - y2_output_loss: 0.0635 - y1_output_root_mean_squared_error: 0.2524 - y2_output_root_mean_squared_error: 0.2532 - val_loss: 0.4131 - val_y1_output_loss: 0.1172 - val_y2_output_loss: 0.3115 - val_y1_output_root_mean_squared_error: 0.3461 - val_y2_output_root_mean_squared_error: 0.5416
# Epoch 98/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1380 - y1_output_loss: 0.0676 - y2_output_loss: 0.0703 - y1_output_root_mean_squared_error: 0.2610 - y2_output_root_mean_squared_error: 0.2643 - val_loss: 0.4918 - val_y1_output_loss: 0.1479 - val_y2_output_loss: 0.3562 - val_y1_output_root_mean_squared_error: 0.3904 - val_y2_output_root_mean_squared_error: 0.5825
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.1481 - y1_output_loss: 0.0791 - y2_output_loss: 0.0691 - y1_output_root_mean_squared_error: 0.2812 - y2_output_root_mean_squared_error: 0.2627 - val_loss: 0.4584 - val_y1_output_loss: 0.1338 - val_y2_output_loss: 0.3378 - val_y1_output_root_mean_squared_error: 0.3672 - val_y2_output_root_mean_squared_error: 0.5688
# Epoch 100/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.1304 - y1_output_loss: 0.0678 - y2_output_loss: 0.0630 - y1_output_root_mean_squared_error: 0.2607 - y2_output_root_mean_squared_error: 0.2499 - val_loss: 0.5439 - val_y1_output_loss: 0.1260 - val_y2_output_loss: 0.4329 - val_y1_output_root_mean_squared_error: 0.3589 - val_y2_output_root_mean_squared_error: 0.6442
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2097 - y1_output_loss: 0.0861 - y2_output_loss: 0.1231 - y1_output_root_mean_squared_error: 0.2927 - y2_output_root_mean_squared_error: 0.3521 - val_loss: 0.4432 - val_y1_output_loss: 0.1424 - val_y2_output_loss: 0.3198 - val_y1_output_root_mean_squared_error: 0.3793 - val_y2_output_root_mean_squared_error: 0.5471
# Epoch 102/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.1467 - y1_output_loss: 0.0706 - y2_output_loss: 0.0795 - y1_output_root_mean_squared_error: 0.2592 - y2_output_root_mean_squared_error: 0.2820 - val_loss: 1.1054 - val_y1_output_loss: 0.6305 - val_y2_output_loss: 0.4882 - val_y1_output_root_mean_squared_error: 0.7971 - val_y2_output_root_mean_squared_error: 0.6856
# Epoch 103/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2073 - y1_output_loss: 0.0914 - y2_output_loss: 0.1141 - y1_output_root_mean_squared_error: 0.3037 - y2_output_root_mean_squared_error: 0.3392 - val_loss: 0.4516 - val_y1_output_loss: 0.1379 - val_y2_output_loss: 0.3293 - val_y1_output_root_mean_squared_error: 0.3749 - val_y2_output_root_mean_squared_error: 0.5577
# Epoch 104/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1391 - y1_output_loss: 0.0680 - y2_output_loss: 0.0704 - y1_output_root_mean_squared_error: 0.2613 - y2_output_root_mean_squared_error: 0.2661 - val_loss: 0.5794 - val_y1_output_loss: 0.1679 - val_y2_output_loss: 0.4183 - val_y1_output_root_mean_squared_error: 0.4163 - val_y2_output_root_mean_squared_error: 0.6373
# Epoch 105/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1541 - y1_output_loss: 0.0731 - y2_output_loss: 0.0811 - y1_output_root_mean_squared_error: 0.2692 - y2_output_root_mean_squared_error: 0.2857 - val_loss: 0.5104 - val_y1_output_loss: 0.1877 - val_y2_output_loss: 0.3408 - val_y1_output_root_mean_squared_error: 0.4322 - val_y2_output_root_mean_squared_error: 0.5689
# Epoch 106/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1216 - y1_output_loss: 0.0658 - y2_output_loss: 0.0557 - y1_output_root_mean_squared_error: 0.2570 - y2_output_root_mean_squared_error: 0.2358 - val_loss: 0.4749 - val_y1_output_loss: 0.1376 - val_y2_output_loss: 0.3488 - val_y1_output_root_mean_squared_error: 0.3739 - val_y2_output_root_mean_squared_error: 0.5789
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1268 - y1_output_loss: 0.0667 - y2_output_loss: 0.0599 - y1_output_root_mean_squared_error: 0.2594 - y2_output_root_mean_squared_error: 0.2438 - val_loss: 0.5491 - val_y1_output_loss: 0.1290 - val_y2_output_loss: 0.4235 - val_y1_output_root_mean_squared_error: 0.3641 - val_y2_output_root_mean_squared_error: 0.6454
# Epoch 108/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.1429 - y1_output_loss: 0.0719 - y2_output_loss: 0.0724 - y1_output_root_mean_squared_error: 0.2676 - y2_output_root_mean_squared_error: 0.2671 - val_loss: 0.6843 - val_y1_output_loss: 0.1929 - val_y2_output_loss: 0.5095 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.7000
# Epoch 109/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1681 - y1_output_loss: 0.0766 - y2_output_loss: 0.0915 - y1_output_root_mean_squared_error: 0.2760 - y2_output_root_mean_squared_error: 0.3032 - val_loss: 0.4297 - val_y1_output_loss: 0.1427 - val_y2_output_loss: 0.3041 - val_y1_output_root_mean_squared_error: 0.3794 - val_y2_output_root_mean_squared_error: 0.5345
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1318 - y1_output_loss: 0.0685 - y2_output_loss: 0.0631 - y1_output_root_mean_squared_error: 0.2627 - y2_output_root_mean_squared_error: 0.2506 - val_loss: 0.4576 - val_y1_output_loss: 0.1356 - val_y2_output_loss: 0.3329 - val_y1_output_root_mean_squared_error: 0.3728 - val_y2_output_root_mean_squared_error: 0.5645
# Epoch 111/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.1163 - y1_output_loss: 0.0635 - y2_output_loss: 0.0528 - y1_output_root_mean_squared_error: 0.2519 - y2_output_root_mean_squared_error: 0.2298 - val_loss: 0.4784 - val_y1_output_loss: 0.1489 - val_y2_output_loss: 0.3403 - val_y1_output_root_mean_squared_error: 0.3903 - val_y2_output_root_mean_squared_error: 0.5711
# Epoch 112/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.1235 - y1_output_loss: 0.0685 - y2_output_loss: 0.0541 - y1_output_root_mean_squared_error: 0.2627 - y2_output_root_mean_squared_error: 0.2335 - val_loss: 0.4427 - val_y1_output_loss: 0.1454 - val_y2_output_loss: 0.3052 - val_y1_output_root_mean_squared_error: 0.3855 - val_y2_output_root_mean_squared_error: 0.5423
# Epoch 113/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1229 - y1_output_loss: 0.0703 - y2_output_loss: 0.0517 - y1_output_root_mean_squared_error: 0.2663 - y2_output_root_mean_squared_error: 0.2280 - val_loss: 0.4198 - val_y1_output_loss: 0.1293 - val_y2_output_loss: 0.3033 - val_y1_output_root_mean_squared_error: 0.3632 - val_y2_output_root_mean_squared_error: 0.5366
# Epoch 114/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.1124 - y1_output_loss: 0.0598 - y2_output_loss: 0.0519 - y1_output_root_mean_squared_error: 0.2455 - y2_output_root_mean_squared_error: 0.2284 - val_loss: 0.4571 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.3105 - val_y1_output_root_mean_squared_error: 0.3997 - val_y2_output_root_mean_squared_error: 0.5453
# Epoch 115/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.1712 - y1_output_loss: 0.0727 - y2_output_loss: 0.0979 - y1_output_root_mean_squared_error: 0.2707 - y2_output_root_mean_squared_error: 0.3129 - val_loss: 0.4617 - val_y1_output_loss: 0.1374 - val_y2_output_loss: 0.3341 - val_y1_output_root_mean_squared_error: 0.3741 - val_y2_output_root_mean_squared_error: 0.5672
# Epoch 116/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.1124 - y1_output_loss: 0.0632 - y2_output_loss: 0.0493 - y1_output_root_mean_squared_error: 0.2512 - y2_output_root_mean_squared_error: 0.2222 - val_loss: 0.6014 - val_y1_output_loss: 0.1481 - val_y2_output_loss: 0.4655 - val_y1_output_root_mean_squared_error: 0.3897 - val_y2_output_root_mean_squared_error: 0.6705
# Epoch 117/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1553 - y1_output_loss: 0.0662 - y2_output_loss: 0.0888 - y1_output_root_mean_squared_error: 0.2581 - y2_output_root_mean_squared_error: 0.2978 - val_loss: 0.6537 - val_y1_output_loss: 0.1681 - val_y2_output_loss: 0.4946 - val_y1_output_root_mean_squared_error: 0.4135 - val_y2_output_root_mean_squared_error: 0.6947
# Epoch 118/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.1736 - y1_output_loss: 0.0780 - y2_output_loss: 0.0946 - y1_output_root_mean_squared_error: 0.2804 - y2_output_root_mean_squared_error: 0.3083 - val_loss: 0.5482 - val_y1_output_loss: 0.1311 - val_y2_output_loss: 0.4282 - val_y1_output_root_mean_squared_error: 0.3652 - val_y2_output_root_mean_squared_error: 0.6441
# Epoch 119/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.1413 - y1_output_loss: 0.0681 - y2_output_loss: 0.0743 - y1_output_root_mean_squared_error: 0.2599 - y2_output_root_mean_squared_error: 0.2716 - val_loss: 0.5425 - val_y1_output_loss: 0.1613 - val_y2_output_loss: 0.3822 - val_y1_output_root_mean_squared_error: 0.4066 - val_y2_output_root_mean_squared_error: 0.6142
# Epoch 120/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.1416 - y1_output_loss: 0.0694 - y2_output_loss: 0.0715 - y1_output_root_mean_squared_error: 0.2644 - y2_output_root_mean_squared_error: 0.2679 - val_loss: 0.4497 - val_y1_output_loss: 0.1319 - val_y2_output_loss: 0.3308 - val_y1_output_root_mean_squared_error: 0.3647 - val_y2_output_root_mean_squared_error: 0.5627
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.1216 - y1_output_loss: 0.0615 - y2_output_loss: 0.0608 - y1_output_root_mean_squared_error: 0.2470 - y2_output_root_mean_squared_error: 0.2460 - val_loss: 0.6487 - val_y1_output_loss: 0.1762 - val_y2_output_loss: 0.4745 - val_y1_output_root_mean_squared_error: 0.4259 - val_y2_output_root_mean_squared_error: 0.6836
# Epoch 462/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.1469 - y1_output_loss: 0.0734 - y2_output_loss: 0.0723 - y1_output_root_mean_squared_error: 0.2720 - y2_output_root_mean_squared_error: 0.2701 - val_loss: 0.4339 - val_y1_output_loss: 0.1579 - val_y2_output_loss: 0.2859 - val_y1_output_root_mean_squared_error: 0.4003 - val_y2_output_root_mean_squared_error: 0.5231
# Epoch 463/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.1042 - y1_output_loss: 0.0570 - y2_output_loss: 0.0473 - y1_output_root_mean_squared_error: 0.2391 - y2_output_root_mean_squared_error: 0.2169 - val_loss: 0.5643 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.3892 - val_y1_output_root_mean_squared_error: 0.4329 - val_y2_output_root_mean_squared_error: 0.6140
# Epoch 464/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.0917 - y1_output_loss: 0.0577 - y2_output_loss: 0.0336 - y1_output_root_mean_squared_error: 0.2407 - y2_output_root_mean_squared_error: 0.1839 - val_loss: 0.4180 - val_y1_output_loss: 0.1307 - val_y2_output_loss: 0.2942 - val_y1_output_root_mean_squared_error: 0.3657 - val_y2_output_root_mean_squared_error: 0.5332
# Epoch 465/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.1130 - y1_output_loss: 0.0647 - y2_output_loss: 0.0473 - y1_output_root_mean_squared_error: 0.2554 - y2_output_root_mean_squared_error: 0.2186 - val_loss: 0.4309 - val_y1_output_loss: 0.1478 - val_y2_output_loss: 0.2893 - val_y1_output_root_mean_squared_error: 0.3893 - val_y2_output_root_mean_squared_error: 0.5285
# Epoch 466/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1167 - y1_output_loss: 0.0651 - y2_output_loss: 0.0529 - y1_output_root_mean_squared_error: 0.2525 - y2_output_root_mean_squared_error: 0.2302 - val_loss: 0.5465 - val_y1_output_loss: 0.2394 - val_y2_output_loss: 0.3084 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 0.5469
# Epoch 467/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.1128 - y1_output_loss: 0.0612 - y2_output_loss: 0.0512 - y1_output_root_mean_squared_error: 0.2481 - y2_output_root_mean_squared_error: 0.2264 - val_loss: 0.4543 - val_y1_output_loss: 0.1358 - val_y2_output_loss: 0.3228 - val_y1_output_root_mean_squared_error: 0.3737 - val_y2_output_root_mean_squared_error: 0.5609
# Epoch 468/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.1177 - y1_output_loss: 0.0596 - y2_output_loss: 0.0577 - y1_output_root_mean_squared_error: 0.2448 - y2_output_root_mean_squared_error: 0.2404 - val_loss: 0.4210 - val_y1_output_loss: 0.1434 - val_y2_output_loss: 0.2842 - val_y1_output_root_mean_squared_error: 0.3827 - val_y2_output_root_mean_squared_error: 0.5240
# Epoch 469/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.1058 - y1_output_loss: 0.0559 - y2_output_loss: 0.0501 - y1_output_root_mean_squared_error: 0.2370 - y2_output_root_mean_squared_error: 0.2226 - val_loss: 0.4980 - val_y1_output_loss: 0.1382 - val_y2_output_loss: 0.3754 - val_y1_output_root_mean_squared_error: 0.3728 - val_y2_output_root_mean_squared_error: 0.5991
# Epoch 470/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.1245 - y1_output_loss: 0.0634 - y2_output_loss: 0.0617 - y1_output_root_mean_squared_error: 0.2502 - y2_output_root_mean_squared_error: 0.2488 - val_loss: 0.5508 - val_y1_output_loss: 0.2121 - val_y2_output_loss: 0.3403 - val_y1_output_root_mean_squared_error: 0.4674 - val_y2_output_root_mean_squared_error: 0.5765
# Epoch 471/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.0999 - y1_output_loss: 0.0577 - y2_output_loss: 0.0414 - y1_output_root_mean_squared_error: 0.2411 - y2_output_root_mean_squared_error: 0.2043 - val_loss: 0.4181 - val_y1_output_loss: 0.1320 - val_y2_output_loss: 0.2906 - val_y1_output_root_mean_squared_error: 0.3679 - val_y2_output_root_mean_squared_error: 0.5318
# Epoch 472/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.0889 - y1_output_loss: 0.0535 - y2_output_loss: 0.0348 - y1_output_root_mean_squared_error: 0.2320 - y2_output_root_mean_squared_error: 0.1873 - val_loss: 0.4258 - val_y1_output_loss: 0.1336 - val_y2_output_loss: 0.2976 - val_y1_output_root_mean_squared_error: 0.3696 - val_y2_output_root_mean_squared_error: 0.5377
# Epoch 473/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.0994 - y1_output_loss: 0.0561 - y2_output_loss: 0.0428 - y1_output_root_mean_squared_error: 0.2377 - y2_output_root_mean_squared_error: 0.2070 - val_loss: 0.4428 - val_y1_output_loss: 0.1438 - val_y2_output_loss: 0.3064 - val_y1_output_root_mean_squared_error: 0.3823 - val_y2_output_root_mean_squared_error: 0.5446
# Epoch 474/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.0905 - y1_output_loss: 0.0538 - y2_output_loss: 0.0362 - y1_output_root_mean_squared_error: 0.2328 - y2_output_root_mean_squared_error: 0.1907 - val_loss: 0.4971 - val_y1_output_loss: 0.1388 - val_y2_output_loss: 0.3634 - val_y1_output_root_mean_squared_error: 0.3765 - val_y2_output_root_mean_squared_error: 0.5961
# Epoch 475/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1069 - y1_output_loss: 0.0569 - y2_output_loss: 0.0492 - y1_output_root_mean_squared_error: 0.2396 - y2_output_root_mean_squared_error: 0.2225 - val_loss: 0.4411 - val_y1_output_loss: 0.1326 - val_y2_output_loss: 0.3204 - val_y1_output_root_mean_squared_error: 0.3669 - val_y2_output_root_mean_squared_error: 0.5536
# Epoch 476/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.0952 - y1_output_loss: 0.0571 - y2_output_loss: 0.0388 - y1_output_root_mean_squared_error: 0.2391 - y2_output_root_mean_squared_error: 0.1951 - val_loss: 0.5681 - val_y1_output_loss: 0.1690 - val_y2_output_loss: 0.4032 - val_y1_output_root_mean_squared_error: 0.4174 - val_y2_output_root_mean_squared_error: 0.6276
# Epoch 477/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.0912 - y1_output_loss: 0.0554 - y2_output_loss: 0.0351 - y1_output_root_mean_squared_error: 0.2363 - y2_output_root_mean_squared_error: 0.1881 - val_loss: 0.4180 - val_y1_output_loss: 0.1384 - val_y2_output_loss: 0.2846 - val_y1_output_root_mean_squared_error: 0.3765 - val_y2_output_root_mean_squared_error: 0.5255
# Epoch 478/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.1120 - y1_output_loss: 0.0623 - y2_output_loss: 0.0491 - y1_output_root_mean_squared_error: 0.2502 - y2_output_root_mean_squared_error: 0.2222 - val_loss: 0.4263 - val_y1_output_loss: 0.1439 - val_y2_output_loss: 0.2931 - val_y1_output_root_mean_squared_error: 0.3813 - val_y2_output_root_mean_squared_error: 0.5300
# Epoch 479/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.0997 - y1_output_loss: 0.0613 - y2_output_loss: 0.0382 - y1_output_root_mean_squared_error: 0.2480 - y2_output_root_mean_squared_error: 0.1956 - val_loss: 0.4598 - val_y1_output_loss: 0.1649 - val_y2_output_loss: 0.3028 - val_y1_output_root_mean_squared_error: 0.4107 - val_y2_output_root_mean_squared_error: 0.5395
# Epoch 480/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.1100 - y1_output_loss: 0.0611 - y2_output_loss: 0.0482 - y1_output_root_mean_squared_error: 0.2480 - y2_output_root_mean_squared_error: 0.2202 - val_loss: 0.4112 - val_y1_output_loss: 0.1279 - val_y2_output_loss: 0.2926 - val_y1_output_root_mean_squared_error: 0.3607 - val_y2_output_root_mean_squared_error: 0.5301
# Epoch 481/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1096 - y1_output_loss: 0.0629 - y2_output_loss: 0.0462 - y1_output_root_mean_squared_error: 0.2512 - y2_output_root_mean_squared_error: 0.2157 - val_loss: 0.4272 - val_y1_output_loss: 0.1323 - val_y2_output_loss: 0.3038 - val_y1_output_root_mean_squared_error: 0.3671 - val_y2_output_root_mean_squared_error: 0.5407
# Epoch 482/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.0921 - y1_output_loss: 0.0548 - y2_output_loss: 0.0368 - y1_output_root_mean_squared_error: 0.2350 - y2_output_root_mean_squared_error: 0.1922 - val_loss: 0.4385 - val_y1_output_loss: 0.1344 - val_y2_output_loss: 0.3096 - val_y1_output_root_mean_squared_error: 0.3713 - val_y2_output_root_mean_squared_error: 0.5484
# Epoch 483/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.1102 - y1_output_loss: 0.0596 - y2_output_loss: 0.0499 - y1_output_root_mean_squared_error: 0.2449 - y2_output_root_mean_squared_error: 0.2241 - val_loss: 0.4765 - val_y1_output_loss: 0.1599 - val_y2_output_loss: 0.3259 - val_y1_output_root_mean_squared_error: 0.4013 - val_y2_output_root_mean_squared_error: 0.5617
# Epoch 484/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.0942 - y1_output_loss: 0.0553 - y2_output_loss: 0.0396 - y1_output_root_mean_squared_error: 0.2343 - y2_output_root_mean_squared_error: 0.1982 - val_loss: 0.6667 - val_y1_output_loss: 0.2645 - val_y2_output_loss: 0.4135 - val_y1_output_root_mean_squared_error: 0.5150 - val_y2_output_root_mean_squared_error: 0.6336
# Epoch 485/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.0936 - y1_output_loss: 0.0579 - y2_output_loss: 0.0352 - y1_output_root_mean_squared_error: 0.2414 - y2_output_root_mean_squared_error: 0.1879 - val_loss: 0.4222 - val_y1_output_loss: 0.1317 - val_y2_output_loss: 0.2950 - val_y1_output_root_mean_squared_error: 0.3646 - val_y2_output_root_mean_squared_error: 0.5379
# Epoch 486/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.0969 - y1_output_loss: 0.0527 - y2_output_loss: 0.0442 - y1_output_root_mean_squared_error: 0.2289 - y2_output_root_mean_squared_error: 0.2110 - val_loss: 0.4205 - val_y1_output_loss: 0.1330 - val_y2_output_loss: 0.2962 - val_y1_output_root_mean_squared_error: 0.3671 - val_y2_output_root_mean_squared_error: 0.5345
# Epoch 487/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.0856 - y1_output_loss: 0.0519 - y2_output_loss: 0.0340 - y1_output_root_mean_squared_error: 0.2278 - y2_output_root_mean_squared_error: 0.1835 - val_loss: 0.5551 - val_y1_output_loss: 0.1561 - val_y2_output_loss: 0.4044 - val_y1_output_root_mean_squared_error: 0.4013 - val_y2_output_root_mean_squared_error: 0.6278
# Epoch 488/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.1116 - y1_output_loss: 0.0620 - y2_output_loss: 0.0491 - y1_output_root_mean_squared_error: 0.2496 - y2_output_root_mean_squared_error: 0.2221 - val_loss: 0.4423 - val_y1_output_loss: 0.1277 - val_y2_output_loss: 0.3176 - val_y1_output_root_mean_squared_error: 0.3610 - val_y2_output_root_mean_squared_error: 0.5586
# Epoch 489/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.0979 - y1_output_loss: 0.0579 - y2_output_loss: 0.0394 - y1_output_root_mean_squared_error: 0.2415 - y2_output_root_mean_squared_error: 0.1991 - val_loss: 0.4254 - val_y1_output_loss: 0.1429 - val_y2_output_loss: 0.2963 - val_y1_output_root_mean_squared_error: 0.3792 - val_y2_output_root_mean_squared_error: 0.5307
# Epoch 490/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.0981 - y1_output_loss: 0.0545 - y2_output_loss: 0.0440 - y1_output_root_mean_squared_error: 0.2343 - y2_output_root_mean_squared_error: 0.2077 - val_loss: 0.5499 - val_y1_output_loss: 0.1365 - val_y2_output_loss: 0.4221 - val_y1_output_root_mean_squared_error: 0.3719 - val_y2_output_root_mean_squared_error: 0.6416
# Epoch 491/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.0825 - y1_output_loss: 0.0508 - y2_output_loss: 0.0321 - y1_output_root_mean_squared_error: 0.2242 - y2_output_root_mean_squared_error: 0.1796 - val_loss: 0.4883 - val_y1_output_loss: 0.1413 - val_y2_output_loss: 0.3470 - val_y1_output_root_mean_squared_error: 0.3816 - val_y2_output_root_mean_squared_error: 0.5854
# Epoch 492/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.1089 - y1_output_loss: 0.0572 - y2_output_loss: 0.0527 - y1_output_root_mean_squared_error: 0.2370 - y2_output_root_mean_squared_error: 0.2296 - val_loss: 0.5160 - val_y1_output_loss: 0.1906 - val_y2_output_loss: 0.3380 - val_y1_output_root_mean_squared_error: 0.4334 - val_y2_output_root_mean_squared_error: 0.5729
# Epoch 493/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.0971 - y1_output_loss: 0.0572 - y2_output_loss: 0.0400 - y1_output_root_mean_squared_error: 0.2387 - y2_output_root_mean_squared_error: 0.2003 - val_loss: 0.3996 - val_y1_output_loss: 0.1274 - val_y2_output_loss: 0.2836 - val_y1_output_root_mean_squared_error: 0.3568 - val_y2_output_root_mean_squared_error: 0.5219
# Epoch 494/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.1106 - y1_output_loss: 0.0573 - y2_output_loss: 0.0528 - y1_output_root_mean_squared_error: 0.2396 - y2_output_root_mean_squared_error: 0.2308 - val_loss: 0.5042 - val_y1_output_loss: 0.1515 - val_y2_output_loss: 0.3587 - val_y1_output_root_mean_squared_error: 0.3937 - val_y2_output_root_mean_squared_error: 0.5909
# Epoch 495/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.0912 - y1_output_loss: 0.0547 - y2_output_loss: 0.0363 - y1_output_root_mean_squared_error: 0.2342 - y2_output_root_mean_squared_error: 0.1908 - val_loss: 0.4771 - val_y1_output_loss: 0.1849 - val_y2_output_loss: 0.2962 - val_y1_output_root_mean_squared_error: 0.4324 - val_y2_output_root_mean_squared_error: 0.5387
# Epoch 496/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.0871 - y1_output_loss: 0.0533 - y2_output_loss: 0.0331 - y1_output_root_mean_squared_error: 0.2318 - y2_output_root_mean_squared_error: 0.1827 - val_loss: 0.4342 - val_y1_output_loss: 0.1382 - val_y2_output_loss: 0.3083 - val_y1_output_root_mean_squared_error: 0.3736 - val_y2_output_root_mean_squared_error: 0.5428
# Epoch 497/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.1016 - y1_output_loss: 0.0584 - y2_output_loss: 0.0429 - y1_output_root_mean_squared_error: 0.2418 - y2_output_root_mean_squared_error: 0.2077 - val_loss: 0.4354 - val_y1_output_loss: 0.1416 - val_y2_output_loss: 0.3007 - val_y1_output_root_mean_squared_error: 0.3802 - val_y2_output_root_mean_squared_error: 0.5393
# Epoch 498/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.0914 - y1_output_loss: 0.0556 - y2_output_loss: 0.0355 - y1_output_root_mean_squared_error: 0.2364 - y2_output_root_mean_squared_error: 0.1884 - val_loss: 0.4401 - val_y1_output_loss: 0.1327 - val_y2_output_loss: 0.3192 - val_y1_output_root_mean_squared_error: 0.3647 - val_y2_output_root_mean_squared_error: 0.5542
# Epoch 499/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.0879 - y1_output_loss: 0.0535 - y2_output_loss: 0.0336 - y1_output_root_mean_squared_error: 0.2323 - y2_output_root_mean_squared_error: 0.1842 - val_loss: 0.4193 - val_y1_output_loss: 0.1373 - val_y2_output_loss: 0.2910 - val_y1_output_root_mean_squared_error: 0.3725 - val_y2_output_root_mean_squared_error: 0.5297
# Epoch 500/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.1347 - y1_output_loss: 0.0606 - y2_output_loss: 0.0737 - y1_output_root_mean_squared_error: 0.2465 - y2_output_root_mean_squared_error: 0.2720 - val_loss: 0.4585 - val_y1_output_loss: 0.1389 - val_y2_output_loss: 0.3231 - val_y1_output_root_mean_squared_error: 0.3753 - val_y2_output_root_mean_squared_error: 0.5636

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.4585 - y1_output_loss: 0.1484 - y2_output_loss: 0.3179 - y1_output_root_mean_squared_error: 0.3753 - y2_output_root_mean_squared_error: 0.5636
# Loss = 0.45850359774255134, Y1_loss = 0.14839224517345428, Y1_mse = 0.37526360154151917, Y2_loss = 0.31786924600601196, Y2_mse = 0.5636318325996399

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
